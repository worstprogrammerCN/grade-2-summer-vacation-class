# %%
import helper
import re
def get_phonemes_without_number(phonemes):
    phonemes_without_number = []
    for phoneme in phonemes:
        if phoneme[-1].isdigit():
            phonemes_without_number.append(phoneme[:-1])
        else:
            phonemes_without_number.append(phoneme)
    return phonemes_without_number

def preprocess(unprocessed_data):
    X = []
    for line in unprocessed_data:
        pos_primary_stress = -1
        parts = re.split("\s|:", line)
        phonemes = parts[1:]
        phonemes_without_number = get_phonemes_without_number(phonemes)
        word = parts[0]
        vowels = []
        consonants = []
        primary_stress = ""
        
        for index in range(1, len(parts)):
            if re.match('[a-zA-Z]+\d', parts[index]): #若是vowel则尾部必带有数字
                vowels.append(parts[index])
            else:                                   #若是con则必不带数字
                consonants.append(parts[index])
            if parts[index].find('1') != -1: #若含有'1'则是primary_stress
                primary_stress = parts[index]
        
        
        pos_primary_stress_in_vowel = vowels.index(primary_stress) + 1

        if len(vowels) == 2:
            x = [word, phonemes, pos_primary_stress_in_vowel]
            X.append(x)
    X1 = []
    X2 = []
    for x in X:
        if x[2] == 1:
            X1.append(x)
        else:
            X2.append(x)
            print(x)

    return X

training_data = helper.read_data('./asset/training_data.txt')
classifier_path = './asset/classifier.dat'
data = helper.read_data('./asset/training_data.txt')

preprocess(data)
# Out:
# ('ZHAMBU', ['Z', 'AA0', 'M', 'B', 'UW1'], 2)
# ('MCGUIRE', ['M', 'AH0', 'G', 'W', 'AY1', 'R'], 2)
# ('DUNDEE', ['D', 'AH0', 'N', 'D', 'IY1'], 2)
# ('RECEDE', ['R', 'IH0', 'S', 'IY1', 'D'], 2)
# ('BELOVED', ['B', 'IH0', 'L', 'AH1', 'V', 'D'], 2)
# ('ENCROACHED', ['IH0', 'N', 'K', 'R', 'OW1', 'CH', 'T'], 2)
# ('LOCALES', ['L', 'OW0', 'K', 'AE1', 'L', 'Z'], 2)
# ('TODOS', ['T', 'UW2', 'D', 'UW1', 'Z'], 2)
# ('CASHION', ['K', 'AA0', 'SH', 'IY1', 'N'], 2)
# ('MARGAUX', ['M', 'AA0', 'R', 'G', 'OW1'], 2)
# ('MOREL', ['M', 'ER0', 'EH1', 'L'], 2)
# ('LAMARRE', ['L', 'AA0', 'M', 'AA1', 'R'], 2)
# ('MONSIEURS', ['M', 'AH0', 'S', 'Y', 'ER1', 'Z'], 2)
# ('REVIVED', ['R', 'IH0', 'V', 'AY1', 'V', 'D'], 2)
# ('COUTURE', ['K', 'UW0', 'T', 'UH1', 'R'], 2)
# ('INCISED', ['IH2', 'N', 'S', 'AY1', 'Z', 'D'], 2)
# ('BEAUCHAINE', ['B', 'OW2', 'SH', 'EY1', 'N'], 2)
# ('JOANNE', ['JH', 'OW2', 'AE1', 'N'], 2)
# ('BUFETE', ['B', 'Y', 'UW2', 'F', 'IY1', 'T'], 2)
# ('MACHOLD', ['M', 'AH0', 'HH', 'OW1', 'L', 'D'], 2)
# ('CARVEL', ['K', 'AA0', 'R', 'V', 'EH1', 'L'], 2)
# ('LESTRANGE', ['L', 'EH0', 'S', 'T', 'R', 'EY1', 'N', 'JH'], 2)
# ('MIEARS', ['M', 'IY0', 'IH1', 'R', 'Z'], 2)
# ('CLAUDET', ['K', 'L', 'AO0', 'D', 'EH1', 'T'], 2)
# ('GERMAIN', ['JH', 'ER0', 'M', 'EY1', 'N'], 2)
# ('REPAID', ['R', 'IY0', 'P', 'EY1', 'D'], 2)
# ('ABORTS', ['AH0', 'B', 'AO1', 'R', 'T', 'S'], 2)
# ('COERCED', ['K', 'OW0', 'ER1', 'S', 'T'], 2)
# ('REVERB', ['R', 'IY0', 'V', 'ER1', 'B'], 2)
# ('DEMURS', ['D', 'IH0', 'M', 'ER1', 'Z'], 2)
# ('NOELLE', ['N', 'OW0', 'EH1', 'L'], 2)
# ('INDRI', ['IH2', 'N', 'D', 'R', 'IY1'], 2)
# ('RIBAR', ['R', 'IH0', 'B', 'AA1', 'R'], 2)
# ('ENSHROUD', ['IH0', 'N', 'SH', 'R', 'AW1', 'D'], 2)
# ('PORTELL', ['P', 'AO0', 'R', 'T', 'EY1', 'L'], 2)
# ('FERRAR', ['F', 'ER0', 'AA1', 'R'], 2)
# ('AMISS', ['AH0', 'M', 'IH1', 'S'], 2)
# ('VANFLEET', ['V', 'AE2', 'N', 'F', 'L', 'IY1', 'T'], 2)
# ('PROSCRIBED', ['P', 'R', 'OW0', 'S', 'K', 'R', 'AY1', 'B', 'D'], 2)
# ('ASKIN', ['AH0', 'S', 'K', 'IH1', 'N'], 2)
# ('DISPENSED', ['D', 'IH0', 'S', 'P', 'EH1', 'N', 'S', 'T'], 2)
# ('MCFEE', ['M', 'AH0', 'K', 'F', 'IY1'], 2)
# ('DISCREET', ['D', 'IH0', 'S', 'K', 'R', 'IY1', 'T'], 2)
# ('RAHAL', ['R', 'AH0', 'HH', 'AA1', 'L'], 2)
# ('SUBSIST', ['S', 'AH0', 'B', 'S', 'IH1', 'S', 'T'], 2)
# ('MARCELLE', ['M', 'AA0', 'R', 'S', 'EH1', 'L'], 2)
# ('ASCEND', ['AH0', 'S', 'EH1', 'N', 'D'], 2)
# ('CAREENED', ['K', 'ER0', 'IY1', 'N', 'D'], 2)
# ('TRANSFERS', ['T', 'R', 'AE0', 'N', 'S', 'F', 'ER1', 'Z'], 2)
# ('MCKELL', ['M', 'AH0', 'K', 'EH1', 'L'], 2)
# ('MILBOURNE', ['M', 'IH0', 'L', 'B', 'UH1', 'R', 'N'], 2)
# ('IMPACTS', ['IH2', 'M', 'P', 'AE1', 'K', 'T', 'S'], 2)
# ('UNSEAL', ['AH0', 'N', 'S', 'IY1', 'L'], 2)
# ('RELOADS', ['R', 'IY2', 'L', 'OW1', 'D', 'Z'], 2)
# ('ASHAMED', ['AH0', 'SH', 'EY1', 'M', 'D'], 2)
# ('SYLVAIN', ['S', 'IH0', 'L', 'V', 'EY1', 'N'], 2)
# ('DOWNWIND', ['D', 'AW0', 'N', 'W', 'IH1', 'N', 'D'], 2)
# ('BOUTIQUE', ['B', 'UW0', 'T', 'IY1', 'K'], 2)
# ('MCFUN', ['M', 'AH0', 'K', 'F', 'AH1', 'N'], 2)
# ('SALON', ['S', 'AH0', 'L', 'AA1', 'N'], 2)
# ('CORINNE', ['K', 'ER0', 'IY1', 'N'], 2)
# ('MCLOUD', ['M', 'AH0', 'K', 'L', 'AW1', 'D'], 2)
# ('DERANGED', ['D', 'IH0', 'R', 'EY1', 'N', 'JH', 'D'], 2)
# ('MACQUEEN', ['M', 'AH0', 'K', 'W', 'IY1', 'N'], 2)
# ('MAROIS', ['M', 'ER0', 'W', 'AA1'], 2)
# ('EVERT', ['IH0', 'V', 'ER1', 'T'], 2)
# ('BEFALL', ['B', 'IH0', 'F', 'AO1', 'L'], 2)
# ('BONSAI', ['B', 'AA0', 'N', 'S', 'AY1'], 2)
# ('LAURENE', ['L', 'AO0', 'R', 'IY1', 'N'], 2)
# ('AUCOIN', ['OW0', 'K', 'OY1', 'N'], 2)
# ('TRUSTEES', ['T', 'R', 'AH2', 'S', 'T', 'IY1', 'Z'], 2)
# ('UNHINGED', ['AH0', 'N', 'HH', 'IH1', 'N', 'JH', 'D'], 2)
# ('RESEED', ['R', 'IY0', 'S', 'IY1', 'D'], 2)
# ('REDACTES', ['R', 'IH0', 'D', 'AE1', 'K', 'T', 'S'], 2)
# ('MCPIKE', ['M', 'AH0', 'K', 'P', 'AY1', 'K'], 2)
# ('ALTAIR', ['AA0', 'L', 'T', 'EH1', 'R'], 2)
# ('COMBINES', ['K', 'AH0', 'M', 'B', 'AY1', 'N', 'Z'], 2)
# ('EGRESS', ['IH0', 'G', 'R', 'EH1', 'S'], 2)
# ('REFUSED', ['R', 'AH0', 'F', 'Y', 'UW1', 'Z', 'D'], 2)
# ('CURTAILS', ['K', 'ER0', 'T', 'EY1', 'L', 'Z'], 2)
# ('OPPRESSED', ['AH0', 'P', 'R', 'EH1', 'S', 'T'], 2)
# ('INTRIGUES', ['IH2', 'N', 'T', 'R', 'IY1', 'G', 'Z'], 2)
# ('DUQUESNE', ['D', 'UW0', 'K', 'EY1', 'N'], 2)
# ('HARPIN', ['HH', 'AA0', 'R', 'P', 'AE1', 'N'], 2)
# ('SHAHRZAD', ['SH', 'AA2', 'R', 'Z', 'AE1', 'D'], 2)
# ('ADJUDGED', ['AH0', 'JH', 'AH1', 'JH', 'D'], 2)
# ('CHAUFFEURS', ['SH', 'OW0', 'F', 'ER1', 'Z'], 2)
# ('DIGEST', ['D', 'AY0', 'JH', 'EH1', 'S', 'T'], 2)
# ('RETHOUGHT', ['R', 'IY0', 'TH', 'AO1', 'T'], 2)
# ('MACTAN', ['M', 'AH0', 'K', 'T', 'AE1', 'N'], 2)
# ('BURDELL', ['B', 'ER0', 'D', 'EH1', 'L'], 2)
# ('RECANT', ['R', 'IY0', 'K', 'AE1', 'N', 'T'], 2)
# ('NIHEI', ['N', 'IH0', 'HH', 'EY1'], 2)
# ('DEPAZ', ['D', 'AH0', 'P', 'AE1', 'Z'], 2)
# ('FOREARM', ['F', 'AO0', 'R', 'AA1', 'R', 'M'], 2)
# ('SIMONE', ['S', 'IH0', 'M', 'OW1', 'N'], 2)
# ('EXCITES', ['IH0', 'K', 'S', 'AY1', 'T', 'S'], 2)
# ('NGO', ['EH0', 'NG', 'G', 'OW1'], 2)
# ('UNVEIL', ['AH0', 'N', 'V', 'EY1', 'L'], 2)
# ('DUVALL', ['D', 'UW0', 'V', 'AA1', 'L'], 2)
# ('ENDURED', ['EH0', 'N', 'D', 'Y', 'UH1', 'R', 'D'], 2)
# ('APPALL', ['AH0', 'P', 'AO1', 'L'], 2)
# ('JOELLE', ['JH', 'OW0', 'EH1', 'L'], 2)
# ('REPELS', ['R', 'IH0', 'P', 'EH1', 'L', 'Z'], 2)
# ('LAFOSSE', ['L', 'AA0', 'F', 'AA1', 'S'], 2)
# ('DOUCET', ['D', 'UW0', 'S', 'EH1', 'T'], 2)
# ('INHALED', ['IH2', 'N', 'HH', 'EY1', 'L', 'D'], 2)
# ('BADU', ['B', 'AH0', 'D', 'UW1'], 2)
# ('PREMIERES', ['P', 'R', 'EH0', 'M', 'IH1', 'R', 'Z'], 2)
# ('LAZEAR', ['L', 'AH0', 'Z', 'IH1', 'R'], 2)
# ('CASAL', ['K', 'AA0', 'S', 'AA1', 'L'], 2)
# ('CONTRIVE', ['K', 'AH0', 'N', 'T', 'R', 'AY1', 'V'], 2)
# ('ETESS', ['EH2', 'T', 'EH1', 'S'], 2)
# ('AILEEN', ['AY0', 'L', 'IY1', 'N'], 2)
# ('LOUISETTE', ['L', 'W', 'IY0', 'Z', 'EH1', 'T'], 2)
# ('UNNAMED', ['AH0', 'N', 'N', 'EY1', 'M', 'D'], 2)
# ('ALAIN', ['AH0', 'L', 'EY1', 'N'], 2)
# ('DECLERK', ['D', 'AH0', 'K', 'L', 'ER1', 'K'], 2)
# ('MCVAY', ['M', 'AH0', 'K', 'V', 'EY1'], 2)
# ('MCCOOL', ['M', 'AH0', 'K', 'UW1', 'L'], 2)
# ('LAGOONS', ['L', 'AH0', 'G', 'UW1', 'N', 'Z'], 2)
# ('TREMAINE', ['T', 'R', 'IH0', 'M', 'EY1', 'N'], 2)
# ('LIENAU', ['L', 'AH0', 'N', 'OW1'], 2)
# ('LAVIGNE', ['L', 'AH0', 'V', 'IH1', 'N', 'Y'], 2)
# ('CONRADES', ['K', 'AH0', 'N', 'R', 'EY1', 'D', 'Z'], 2)
# ('BENARD', ['B', 'IH0', 'N', 'AA1', 'R', 'D'], 2)
# ('GAMEZ', ['G', 'AA0', 'M', 'EH1', 'Z'], 2)
# ('AKAI', ['AH0', 'K', 'AY1'], 2)
# ('VAGUINE', ['V', 'AH0', 'G', 'W', 'IY1', 'N'], 2)
# ('CHATEAUX', ['SH', 'AH0', 'T', 'OW1'], 2)
# ('SAIF', ['S', 'AA2', 'IY1', 'F'], 2)
# ('SAYED', ['S', 'AA2', 'Y', 'EH1', 'D'], 2)
# ('DEBUNKED', ['D', 'IH0', 'B', 'AH1', 'NG', 'K', 'T'], 2)
# ('COMEAUX', ['K', 'AH0', 'M', 'OW1'], 2)
# ('OUTWEIGHED', ['AW0', 'T', 'W', 'EY1', 'D'], 2)
# ('OUIMETTE', ['W', 'IY0', 'M', 'EH1', 'T'], 2)
# ('AKEY', ['AH0', 'K', 'IY1'], 2)
# ('CARDON', ['K', 'AA0', 'R', 'D', 'AO1', 'N'], 2)
# ('EQUATE', ['IH0', 'K', 'W', 'EY1', 'T'], 2)
# ('MACOUTE', ['M', 'AH0', 'K', 'UW1', 'T'], 2)
# ('DECOY', ['D', 'AH0', 'K', 'OY1'], 2)
# ('INFLAME', ['IH0', 'N', 'F', 'L', 'EY1', 'M'], 2)
# ('FANGUY', ['F', 'AH0', 'NG', 'G', 'W', 'IY1'], 2)
# ('NORTHWEST', ['N', 'AO2', 'R', 'TH', 'W', 'EH1', 'S', 'T'], 2)
# ('COMPOSE', ['K', 'AH0', 'M', 'P', 'OW1', 'Z'], 2)
# ('LAFOY', ['L', 'AA0', 'F', 'OY1'], 2)
# ('DISMAYED', ['D', 'IH0', 'S', 'M', 'EY1', 'D'], 2)
# ('UNDOCK', ['AH0', 'N', 'D', 'AA1', 'K'], 2)
# ('ORDEALS', ['AO0', 'R', 'D', 'IY1', 'L', 'Z'], 2)
# ('IMPALED', ['IH2', 'M', 'P', 'EY1', 'L', 'D'], 2)
# ('DISCOUNTS', ['D', 'IH0', 'S', 'K', 'AW1', 'N', 'T', 'S'], 2)
# ('OCLAIR', ['OW0', 'K', 'L', 'ER1'], 2)
# ('QUARTETS', ['K', 'W', 'AO0', 'R', 'T', 'EH1', 'T', 'S'], 2)
# ('ALCON', ['AH0', 'L', 'K', 'AA1', 'N'], 2)
# ('CASALS', ['K', 'AA0', 'S', 'AA1', 'L', 'Z'], 2)
# ('OBEIRNE', ['OW0', 'B', 'ER1', 'R', 'N'], 2)
# ('ARRAYED', ['ER0', 'EY1', 'D'], 2)
# ('REMOTE', ['R', 'IH0', 'M', 'OW1', 'T'], 2)
# ('REMOVES', ['R', 'IY0', 'M', 'UW1', 'V', 'Z'], 2)
# ('PERSPIRE', ['P', 'ER0', 'S', 'P', 'AY1', 'R'], 2)
# ('BOURGOIN', ['B', 'UH0', 'R', 'G', 'OY1', 'N'], 2)
# ('AMON', ['AA0', 'M', 'AO1', 'N'], 2)
# ('EUGENE', ['Y', 'UW0', 'JH', 'IY1', 'N'], 2)
# ('MISJUDGED', ['M', 'IH0', 'S', 'JH', 'AH1', 'JH', 'D'], 2)
# ('APPEALED', ['AH0', 'P', 'IY1', 'L', 'D'], 2)
# ('YOURSELVES', ['Y', 'UH0', 'R', 'S', 'EH1', 'L', 'V', 'Z'], 2)
# ('BELIEVE', ['B', 'IH0', 'L', 'IY1', 'V'], 2)
# ('OROURKE', ['ER0', 'UH1', 'R', 'K'], 2)
# ('ADOPTS', ['AH0', 'D', 'AA1', 'P', 'T', 'S'], 2)
# ('RETURNED', ['R', 'IH0', 'T', 'ER1', 'N', 'D'], 2)
# ('POQUETTE', ['P', 'AH0', 'K', 'EH1', 'T'], 2)
# ('EMLYNNE', ['IH0', 'M', 'L', 'AY1', 'N'], 2)
# ('CONJOIN', ['K', 'AA2', 'N', 'JH', 'OY1', 'N'], 2)
# ('FERDON', ['F', 'EH0', 'R', 'D', 'AO1', 'N'], 2)
# ('ACUFF', ['AH0', 'K', 'AH1', 'F'], 2)
# ('SIELAFF', ['S', 'IY0', 'L', 'AE1', 'F'], 2)
# ('DISEASE', ['D', 'IH0', 'Z', 'IY1', 'Z'], 2)
# ('INFLICT', ['IH2', 'N', 'F', 'L', 'IH1', 'K', 'T'], 2)
# ('UNCORK', ['AH0', 'N', 'K', 'AO1', 'R', 'K'], 2)
# ('DEBASED', ['D', 'AH0', 'B', 'EY1', 'S', 'T'], 2)
# ('IFILL', ['AY2', 'F', 'IY1', 'L'], 2)
# ('TAMEZ', ['T', 'AA0', 'M', 'EH1', 'Z'], 2)
# ('NONGREEK', ['N', 'AA2', 'N', 'G', 'R', 'IY1', 'K'], 2)
# ('ESKIN', ['IH0', 'S', 'K', 'IH1', 'N'], 2)
# ('LUMPUR', ['L', 'AH2', 'M', 'P', 'UH1', 'R'], 2)
# ('MAINORD', ['M', 'EH0', 'N', 'AO1', 'R', 'D'], 2)
# ('RENEAU', ['R', 'IH0', 'N', 'OW1'], 2)
# ('EXTENT', ['IH0', 'K', 'S', 'T', 'EH1', 'N', 'T'], 2)
# ('EMERSE', ['IH0', 'M', 'ER1', 'S'], 2)
# ('ENSCONCED', ['IH0', 'N', 'S', 'K', 'AA1', 'N', 'S', 'T'], 2)
# ('BERMUDES', ['B', 'ER0', 'M', 'Y', 'UW1', 'D', 'Z'], 2)
# ('GUINYARD', ['G', 'IH0', 'N', 'Y', 'AA1', 'R', 'D'], 2)
# ('BOUTIQUES', ['B', 'UW0', 'T', 'IY1', 'K', 'S'], 2)
# ('JAQUEZ', ['Y', 'AA0', 'K', 'W', 'EH1', 'Z'], 2)
# ('BENZENE', ['B', 'EH0', 'N', 'Z', 'IY1', 'N'], 2)
# ('KORAN', ['K', 'AO0', 'R', 'AA1', 'N'], 2)
# ('AFFLICTS', ['AH0', 'F', 'L', 'IH1', 'K', 'T', 'S'], 2)
# ('RASHID', ['R', 'AH0', 'SH', 'IY1', 'D'], 2)
# ('JANDREAU', ['ZH', 'AH0', 'N', 'D', 'R', 'OW1'], 2)
# ('ARKOSE', ['AA0', 'R', 'K', 'OW1', 'S'], 2)
# ('BEREAVED', ['B', 'ER0', 'IY1', 'V', 'D'], 2)
# ('PERUSE', ['P', 'ER0', 'UW1', 'Z'], 2)
# ('IMMERSE', ['IH2', 'M', 'ER1', 'S'], 2)
# ('REJOINS', ['R', 'IY0', 'JH', 'OY1', 'N', 'Z'], 2)
# ('CARRELL', ['K', 'AA0', 'R', 'EY1', 'L'], 2)
# ('MADRID', ['M', 'AH0', 'D', 'R', 'IH1', 'D'], 2)
# ('DURAND', ['D', 'UH0', 'R', 'AA1', 'N', 'D'], 2)
# ('ORNETTE', ['AO2', 'R', 'N', 'EH1', 'T'], 2)
# ('OUTSTRIP', ['AW0', 'T', 'S', 'T', 'R', 'IH1', 'P'], 2)
# ('DENARD', ['D', 'IH0', 'N', 'AA1', 'R', 'D'], 2)
# ('WHEREAS', ['W', 'EH0', 'R', 'AE1', 'Z'], 2)
# ('MCQUAIDE', ['M', 'AH0', 'K', 'W', 'EY1', 'D'], 2)
# ('POSTPONES', ['P', 'OW0', 'S', 'T', 'P', 'OW1', 'N', 'Z'], 2)
# ('MACGRAW', ['M', 'AH0', 'G', 'R', 'AA1'], 2)
# ('DENEAULT', ['D', 'IH0', 'N', 'OW1'], 2)
# ('BEAUCHENE', ['B', 'OW2', 'SH', 'EY1', 'N'], 2)
# ('SUSANN', ['S', 'UW2', 'Z', 'AE1', 'N'], 2)
# ('GRENADE', ['G', 'R', 'AH0', 'N', 'EY1', 'D'], 2)
# ('INERT', ['IH2', 'N', 'ER1', 'T'], 2)
# ('SAVILL', ['S', 'AA0', 'V', 'IY1', 'L'], 2)
# ('MARCOTTE', ['M', 'AA0', 'R', 'K', 'AO1', 'T'], 2)
# ('PERCENT', ['P', 'ER0', 'S', 'EH1', 'N', 'T'], 2)
# ('VANHORN', ['V', 'AE0', 'N', 'HH', 'AO1', 'R', 'N'], 2)
# ('GRANDEUR', ['G', 'R', 'AE0', 'N', 'D', 'UW1', 'R'], 2)
# ('CONDEMN', ['K', 'AH0', 'N', 'D', 'EH1', 'M'], 2)
# ('ADEL', ['AH0', 'D', 'EH1', 'L'], 2)
# ('AMOUR', ['AA2', 'M', 'UW1', 'R'], 2)
# ('BACKENDS', ['B', 'AE2', 'K', 'EH1', 'N', 'D', 'Z'], 2)
# ('PERMUTE', ['P', 'ER2', 'M', 'Y', 'UW1', 'T'], 2)
# ('AWARE', ['AH0', 'W', 'EH1', 'R'], 2)
# ('NADINE', ['N', 'AH0', 'D', 'IY1', 'N'], 2)
# ('EGNEW', ['IH0', 'G', 'N', 'UW1'], 2)
# ('VANBRUNT', ['V', 'AE2', 'N', 'B', 'R', 'AH1', 'N', 'T'], 2)
# ('AMID', ['AH0', 'M', 'IH1', 'D'], 2)
# ('SHAMPOOED', ['SH', 'AE0', 'M', 'P', 'UW1', 'D'], 2)
# ('ONEAL', ['OW0', 'N', 'IY1', 'L'], 2)
# ('INAEZ', ['IH2', 'N', 'AE1', 'Z'], 2)
# ('TRANSPLANT', ['T', 'R', 'AE0', 'N', 'S', 'P', 'L', 'AE1', 'N', 'T'], 2)
# ('MARROU', ['M', 'AH0', 'R', 'UW1'], 2)
# ('CABOOSE', ['K', 'AH0', 'B', 'UW1', 'S'], 2)
# ('INVENT', ['IH2', 'N', 'V', 'EH1', 'N', 'T'], 2)
# ('RECUSE', ['R', 'IH2', 'K', 'Y', 'UW1', 'Z'], 2)
# ('OUTFLANKED', ['AW0', 'T', 'F', 'L', 'AE1', 'NG', 'K', 'T'], 2)
# ('ANNOY', ['AH0', 'N', 'OY1'], 2)
# ('CAMPAIGNS', ['K', 'AE0', 'M', 'P', 'EY1', 'N', 'Z'], 2)
# ('DECREASED', ['D', 'IH0', 'K', 'R', 'IY1', 'S', 'T'], 2)
# ('COTNOIR', ['K', 'AH0', 'T', 'N', 'W', 'AA1', 'R'], 2)
# ('ABOUND', ['AH0', 'B', 'AW1', 'N', 'D'], 2)
# ('RETOOLED', ['R', 'IY0', 'T', 'UW1', 'L', 'D'], 2)
# ('AUDETTE', ['OW0', 'D', 'EH1', 'T'], 2)
# ('RESTRAINED', ['R', 'IY0', 'S', 'T', 'R', 'EY1', 'N', 'D'], 2)
# ('ABOU', ['AH0', 'B', 'UW1'], 2)
# ('THEROUX', ['TH', 'ER0', 'UW1'], 2)
# ('IMMERSED', ['IH2', 'M', 'ER1', 'S', 'T'], 2)
# ('BESEECH', ['B', 'IY0', 'S', 'IY1', 'CH'], 2)
# ('INSTILLED', ['IH2', 'N', 'S', 'T', 'IH1', 'L', 'D'], 2)
# ('AMENDS', ['AH0', 'M', 'EH1', 'N', 'D', 'Z'], 2)
# ('ABELE', ['AH0', 'B', 'EH1', 'L'], 2)
# ('RESTORED', ['R', 'IH0', 'S', 'T', 'AO1', 'R', 'D'], 2)
# ('REMOVE', ['R', 'IY0', 'M', 'UW1', 'V'], 2)
# ('PREPAID', ['P', 'R', 'IY0', 'P', 'EY1', 'D'], 2)
# ('DOUTHIT', ['D', 'UW0', 'TH', 'IH1', 'T'], 2)
# ('GULLETTE', ['G', 'UW0', 'L', 'EH1', 'T'], 2)
# ('AFFECT', ['AH0', 'F', 'EH1', 'K', 'T'], 2)
# ('UNROLLS', ['AH2', 'N', 'R', 'OW1', 'L', 'Z'], 2)
# ('DECEITS', ['D', 'IH0', 'S', 'IY1', 'T', 'S'], 2)
# ('BERNET', ['B', 'ER0', 'N', 'EH1', 'T'], 2)
# ('MORAIS', ['M', 'ER0', 'EY1'], 2)
# ('DUPRIEST', ['D', 'UW2', 'P', 'R', 'IY1', 'S', 'T'], 2)
# ('BESPEAKS', ['B', 'IH0', 'S', 'P', 'IY1', 'K', 'S'], 2)
# ('BRUNETTE', ['B', 'R', 'UW0', 'N', 'EH1', 'T'], 2)
# ('NOUVEAU', ['N', 'UW2', 'V', 'OW1'], 2)
# ('PRETEND', ['P', 'R', 'IY0', 'T', 'EH1', 'N', 'D'], 2)
# ('VANDAELE', ['V', 'AE0', 'N', 'D', 'EH1', 'L'], 2)
# ('REPULSE', ['R', 'IY0', 'P', 'AH1', 'L', 'S'], 2)
# ('RELIED', ['R', 'IH0', 'L', 'AY1', 'D'], 2)
# ('ORSAY', ['AO0', 'R', 'S', 'EY1'], 2)
# ('VERMETTE', ['V', 'ER0', 'M', 'EH1', 'T'], 2)
# ('CAREENS', ['K', 'ER0', 'IY1', 'N', 'Z'], 2)
# ('MACHINE', ['M', 'AH0', 'SH', 'IY1', 'N'], 2)
# ('ENRAGED', ['EH0', 'N', 'R', 'EY1', 'JH', 'D'], 2)
# ('COMPRESSED', ['K', 'AH0', 'M', 'P', 'R', 'EH1', 'S', 'T'], 2)
# ('IDENT', ['AY0', 'D', 'EH1', 'N', 'T'], 2)
# ('DUMAIS', ['D', 'AH0', 'M', 'EY1'], 2)
# ('CONTAINS', ['K', 'AH0', 'N', 'T', 'EY1', 'N', 'Z'], 2)
# ('LABAUVE', ['L', 'AH0', 'B', 'OW1', 'V'], 2)
# ('NAJAR', ['N', 'AA0', 'Y', 'AA1', 'R'], 2)
# ('GAUMOND', ['G', 'OW0', 'M', 'AA1', 'N', 'D'], 2)
# ('DEFLEUR', ['D', 'IH0', 'F', 'L', 'ER1'], 2)
# ('BAPTIZED', ['B', 'AE0', 'P', 'T', 'AY1', 'Z', 'D'], 2)
# ('FRADETTE', ['F', 'R', 'AH0', 'D', 'EH1', 'T'], 2)
# ('GENTEEL', ['JH', 'EH0', 'N', 'T', 'IY1', 'L'], 2)
# ('ENTHRAL', ['EH0', 'N', 'TH', 'R', 'AO1', 'L'], 2)
# ('REPACK', ['R', 'IY0', 'P', 'AE1', 'K'], 2)
# ('YEOSOCK', ['Y', 'OW0', 'S', 'AO1', 'K'], 2)
# ('UNHEARD', ['AH0', 'N', 'HH', 'ER1', 'D'], 2)
# ('BEAUDET', ['B', 'OW0', 'D', 'EH1', 'T'], 2)
# ('RELIEF', ['R', 'IH0', 'L', 'IY1', 'F'], 2)
# ('MOLIERE', ['M', 'OW0', 'L', 'Y', 'EH1', 'R'], 2)
# ('CENTRALE', ['S', 'EH0', 'N', 'T', 'R', 'AA1', 'L'], 2)
# ('MCLIN', ['M', 'AH0', 'K', 'L', 'IH1', 'N'], 2)
# ('GUILFOIL', ['G', 'IH0', 'L', 'F', 'OY1', 'L'], 2)
# ('NEGLECTS', ['N', 'IH0', 'G', 'L', 'EH1', 'K', 'T', 'S'], 2)
# ('MCLAMB', ['M', 'AH0', 'K', 'L', 'AE1', 'M'], 2)
# ('PETITES', ['P', 'EH2', 'T', 'IY1', 'T', 'S'], 2)
# ('MERCI', ['M', 'ER0', 'S', 'IY1'], 2)
# ('ENTWINE', ['EH0', 'N', 'T', 'W', 'AY1', 'N'], 2)
# ('SUFFUSED', ['S', 'AH0', 'F', 'Y', 'UW1', 'Z', 'D'], 2)
# ('LIQUN', ['L', 'IH0', 'K', 'UW1', 'N'], 2)
# ('LANAI', ['L', 'AH0', 'N', 'AY1'], 2)
# ('UNTOUCHED', ['AH0', 'N', 'T', 'AH1', 'CH', 'T'], 2)
# ('ABASHED', ['AH0', 'B', 'AE1', 'SH', 'T'], 2)
# ('MCDILL', ['M', 'AH0', 'K', 'D', 'IH1', 'L'], 2)
# ('SADAO', ['S', 'AH0', 'D', 'AW1'], 2)
# ('MACHINES', ['M', 'AH0', 'SH', 'IY1', 'N', 'Z'], 2)
# ('EXIST', ['IH0', 'G', 'Z', 'IH1', 'S', 'T'], 2)
# ('POUSSAINT', ['P', 'UW2', 'S', 'AA1', 'N', 'T'], 2)
# ('LABRECQUE', ['L', 'AH0', 'B', 'R', 'EH1', 'K'], 2)
# ('FLEURETTE', ['F', 'L', 'ER2', 'EH1', 'T'], 2)
# ('DELBOSQUE', ['D', 'IH0', 'L', 'B', 'OW1', 'S', 'K'], 2)
# ('MACBRIDE', ['M', 'AH0', 'K', 'B', 'R', 'AY1', 'D'], 2)
# ('REVEALED', ['R', 'IH0', 'V', 'IY1', 'L', 'D'], 2)
# ('OUTSCORES', ['AW0', 'T', 'S', 'K', 'AO1', 'R', 'Z'], 2)
# ('MCVEIGH', ['M', 'AH0', 'K', 'V', 'EY1'], 2)
# ('BELIEFS', ['B', 'IH0', 'L', 'IY1', 'F', 'S'], 2)
# ('CURNUTTE', ['K', 'ER0', 'N', 'AH1', 'T'], 2)
# ('ASHAME', ['AH0', 'SH', 'EY1', 'M'], 2)
# ('OUTSOURCED', ['AW2', 'T', 'S', 'AO1', 'R', 'S', 'T'], 2)
# ('SUBDUED', ['S', 'AH0', 'B', 'D', 'UW1', 'D'], 2)
# ('DEPREZ', ['D', 'EY0', 'P', 'R', 'EH1', 'Z'], 2)
# ('HURRAY', ['HH', 'AH0', 'R', 'EY1'], 2)
# ('UNCLAIMED', ['AH0', 'N', 'K', 'L', 'EY1', 'M', 'D'], 2)
# ('UNTIE', ['AH0', 'N', 'T', 'AY1'], 2)
# ('CLEVITE', ['K', 'L', 'EH0', 'V', 'AY1', 'T'], 2)
# ('KABBAH', ['K', 'AH0', 'B', 'AH1'], 2)
# ('NADAL', ['N', 'AA0', 'D', 'AE1', 'L'], 2)
# ('PREVAIL', ['P', 'R', 'IH0', 'V', 'EY1', 'L'], 2)
# ('BORDEAUX', ['B', 'AO0', 'R', 'D', 'OW1'], 2)
# ('MCCOLM', ['M', 'AH0', 'K', 'OW1', 'M'], 2)
# ('OCCURRED', ['AH0', 'K', 'ER1', 'D'], 2)
# ('RESTART', ['R', 'IY0', 'S', 'T', 'AA1', 'R', 'T'], 2)
# ('MARVELLE', ['M', 'AA0', 'R', 'V', 'EH1', 'L'], 2)
# ('MARQUEE', ['M', 'AA0', 'R', 'K', 'IY1'], 2)
# ('UPHOLD', ['AH0', 'P', 'HH', 'OW1', 'L', 'D'], 2)
# ('BEDECK', ['B', 'IH0', 'D', 'EH1', 'K'], 2)
# ('MARGETTE', ['M', 'AA0', 'R', 'ZH', 'EH1', 'T'], 2)
# ('ENCAMPED', ['IH0', 'N', 'K', 'AE1', 'M', 'P', 'T'], 2)
# ('RENEW', ['R', 'IH0', 'N', 'UW1'], 2)
# ('UNLIKE', ['AH0', 'N', 'L', 'AY1', 'K'], 2)
# ('BOZELL', ['B', 'OW0', 'Z', 'EH1', 'L'], 2)
# ('CONTORT', ['K', 'AH0', 'N', 'T', 'AO1', 'R', 'T'], 2)
# ('AMIT', ['AA2', 'M', 'IY1', 'T'], 2)
# ('INVADES', ['IH2', 'N', 'V', 'EY1', 'D', 'Z'], 2)
# ('SHANDONG', ['SH', 'AA2', 'N', 'D', 'OW1', 'NG'], 2)
# ('VOISEY', ['V', 'W', 'AA2', 'S', 'EY1'], 2)
# ('DIRLAM', ['D', 'ER0', 'L', 'AE1', 'M'], 2)
# ('KAHAN', ['K', 'AH0', 'HH', 'AA1', 'N'], 2)
# ('ROWLETTE', ['R', 'OW2', 'L', 'EH1', 'T'], 2)
# ('REBUILD', ['R', 'IY0', 'B', 'IH1', 'L', 'D'], 2)
# ('CONCEALS', ['K', 'AH0', 'N', 'S', 'IY1', 'L', 'Z'], 2)
# ('ROUTINES', ['R', 'UW0', 'T', 'IY1', 'N', 'Z'], 2)
# ('MCNAIR', ['M', 'AH0', 'K', 'N', 'EH1', 'R'], 2)
# ('FINANCE', ['F', 'AH0', 'N', 'AE1', 'N', 'S'], 2)
# ('DUENEZ', ['D', 'W', 'EH0', 'N', 'EH1', 'Z'], 2)
# ('YOURSELF', ['Y', 'ER0', 'S', 'EH1', 'L', 'F'], 2)
# ('BATAT', ['B', 'AH0', 'T', 'AA1', 'T'], 2)
# ('DEVISE', ['D', 'IH0', 'V', 'AY1', 'Z'], 2)
# ('REPRINT', ['R', 'IY0', 'P', 'R', 'IH1', 'N', 'T'], 2)
# ('OFFSET', ['AO0', 'F', 'S', 'EH1', 'T'], 2)
# ('INEPT', ['IH2', 'N', 'EH1', 'P', 'T'], 2)
# ('PERREAULT', ['P', 'ER0', 'R', 'OW1'], 2)
# ('SOUFFLE', ['S', 'UW0', 'F', 'L', 'EY1'], 2)
# ('DAVAO', ['D', 'AH0', 'V', 'OW1'], 2)
# ('ADULT', ['AH0', 'D', 'AH1', 'L', 'T'], 2)
# ('HARPEL', ['HH', 'AA0', 'R', 'P', 'EH1', 'L'], 2)
# ('MAXIME', ['M', 'AE0', 'K', 'S', 'IY1', 'M'], 2)
# ('CAOUETTE', ['K', 'AE2', 'W', 'EH1', 'T'], 2)
# ('ENTRAPPED', ['IH0', 'N', 'T', 'R', 'AE1', 'P', 'T'], 2)
# ('SINISE', ['S', 'IH0', 'N', 'IY1', 'Z'], 2)
# ('LEZOTTE', ['L', 'IH0', 'Z', 'AO1', 'T'], 2)
# ('RESIGN', ['R', 'IH0', 'Z', 'AY1', 'N'], 2)
# ('ASAF', ['AA0', 'S', 'AA1', 'F'], 2)
# ('UNO', ['AH0', 'N', 'OW1'], 2)
# ('EHUD', ['EH0', 'HH', 'AH1', 'D'], 2)
# ('ASSAF', ['AH0', 'S', 'AE1', 'F'], 2)
# ('CHMIEL', ['CH', 'AH0', 'M', 'IY1', 'L'], 2)
# ('CHARLAYNE', ['SH', 'AA0', 'R', 'L', 'EY1', 'N'], 2)
# ('PARADE', ['P', 'ER0', 'EY1', 'D'], 2)
# ('SHORTCHANGE', ['SH', 'AO2', 'R', 'T', 'CH', 'EY1', 'N', 'JH'], 2)
# ('CHARLEEN', ['CH', 'AA0', 'R', 'L', 'IY1', 'N'], 2)
# ('TECHNIQUE', ['T', 'EH0', 'K', 'N', 'IY1', 'K'], 2)
# ('ALLBAUGH', ['AH0', 'L', 'B', 'AO1'], 2)
# ('CORNELLE', ['K', 'ER0', 'N', 'EH1', 'L'], 2)
# ('ASCENDS', ['AH0', 'S', 'EH1', 'N', 'D', 'Z'], 2)
# ('ASLAN', ['AE0', 'S', 'L', 'AH1', 'N'], 2)
# ('ROUNDTRIP', ['R', 'AW2', 'N', 'D', 'T', 'R', 'IH1', 'P'], 2)
# ('MAGOUIRK', ['M', 'AH0', 'G', 'W', 'ER1', 'K'], 2)
# ('IREENE', ['AY0', 'R', 'IY1', 'N'], 2)
# ('UNSKILLED', ['AH0', 'N', 'S', 'K', 'IH1', 'L', 'D'], 2)
# ('DESSERT', ['D', 'IH0', 'Z', 'ER1', 'T'], 2)
# ('POSTPONED', ['P', 'OW0', 'S', 'T', 'P', 'OW1', 'N', 'D'], 2)
# ('DISGUST', ['D', 'IH0', 'S', 'G', 'AH1', 'S', 'T'], 2)
# ('OMITS', ['OW0', 'M', 'IH1', 'T', 'S'], 2)
# ('AFFINES', ['AH0', 'F', 'AY1', 'N', 'Z'], 2)
# ('FARISS', ['F', 'ER0', 'IH1', 'S'], 2)
# ('TABOOS', ['T', 'AE0', 'B', 'UW1', 'Z'], 2)
# ('CONNECTS', ['K', 'AH0', 'N', 'EH1', 'K', 'T', 'S'], 2)
# ('ACCRUED', ['AH0', 'K', 'R', 'UW1', 'D'], 2)
# ('MCGILL', ['M', 'AH0', 'G', 'IH1', 'L'], 2)
# ('SAUTEED', ['S', 'AO0', 'T', 'EY1', 'D'], 2)
# ('PARFAITS', ['P', 'AA2', 'R', 'F', 'EY1', 'Z'], 2)
# ('UNDID', ['AH2', 'N', 'D', 'IH1', 'D'], 2)
# ('EXCELLED', ['IH0', 'K', 'S', 'EH1', 'L', 'D'], 2)
# ('AUSTERE', ['AO0', 'S', 'T', 'IH1', 'R'], 2)
# ('CORRAL', ['K', 'ER0', 'AE1', 'L'], 2)
# ('DEVOLVED', ['D', 'IH0', 'V', 'AA1', 'L', 'V', 'D'], 2)
# ('KILLEEN', ['K', 'IH0', 'L', 'IY1', 'N'], 2)
# ('APPROVED', ['AH0', 'P', 'R', 'UW1', 'V', 'D'], 2)
# ('FAUCHEUX', ['F', 'OW0', 'SH', 'OW1'], 2)
# ('TURBOT', ['T', 'ER2', 'B', 'OW1'], 2)
# ('UNFILLED', ['AH0', 'N', 'F', 'IH1', 'L', 'D'], 2)
# ('JAPANS', ['JH', 'AH0', 'P', 'AE1', 'N', 'Z'], 2)
# ('RETIRES', ['R', 'IH0', 'T', 'AY1', 'R', 'Z'], 2)
# ('REGAIN', ['R', 'IH0', 'G', 'EY1', 'N'], 2)
# ('REBOUND', ['R', 'IY0', 'B', 'AW1', 'N', 'D'], 2)
# ('ACCEPT', ['AE0', 'K', 'S', 'EH1', 'P', 'T'], 2)
# ('BAUCUM', ['B', 'OW0', 'K', 'AH1', 'M'], 2)
# ('VANLIERE', ['V', 'AE0', 'N', 'L', 'IH1', 'R'], 2)
# ('VOLTAIRE', ['V', 'OW0', 'L', 'T', 'EH1', 'R'], 2)
# ('REFUTE', ['R', 'IH0', 'F', 'Y', 'UW1', 'T'], 2)
# ('EDELL', ['IH0', 'D', 'EH1', 'L'], 2)
# ('ENROLL', ['EH0', 'N', 'R', 'OW1', 'L'], 2)
# ('CARTEL', ['K', 'AA0', 'R', 'T', 'EH1', 'L'], 2)
# ('DROGOUL', ['D', 'R', 'OW0', 'G', 'UW1', 'L'], 2)
# ('BEHEAD', ['B', 'IH0', 'HH', 'EH1', 'D'], 2)
# ('IMPROVED', ['IH2', 'M', 'P', 'R', 'UW1', 'V', 'D'], 2)
# ('TERRAIN', ['T', 'ER0', 'EY1', 'N'], 2)
# ('ELISE', ['AH0', 'L', 'IY1', 'S'], 2)
# ('CROCHET', ['K', 'R', 'OW0', 'SH', 'EY1'], 2)
# ('BESTRODE', ['B', 'IH0', 'S', 'T', 'R', 'OW1', 'D'], 2)
# ('UNGLUED', ['AH0', 'N', 'G', 'L', 'UW1', 'D'], 2)
# ('ACCLAIM', ['AH0', 'K', 'L', 'EY1', 'M'], 2)
# ('IMPLODE', ['IH2', 'M', 'P', 'L', 'OW1', 'D'], 2)
# ('LEBOW', ['L', 'AH0', 'B', 'OW1'], 2)
# ('KWANGJU', ['K', 'W', 'AA0', 'NG', 'JH', 'UW1'], 2)
# ('GERMAINE', ['ZH', 'ER0', 'M', 'EY1', 'N'], 2)
# ('CATONE', ['K', 'AH0', 'T', 'OW1', 'N'], 2)
# ('REDOUND', ['R', 'IH0', 'D', 'AW1', 'N', 'D'], 2)
# ('TRANSFUSE', ['T', 'R', 'AE0', 'N', 'S', 'F', 'Y', 'UW1', 'Z'], 2)
# ('REDEEMS', ['R', 'AH0', 'D', 'IY1', 'M', 'Z'], 2)
# ('DZHAMBUL', ['JH', 'AE0', 'M', 'B', 'UW1', 'L'], 2)
# ('LECATES', ['L', 'IH0', 'K', 'EY1', 'T', 'S'], 2)
# ('ORDAINED', ['AO0', 'R', 'D', 'EY1', 'N', 'D'], 2)
# ('REMISS', ['R', 'IY0', 'M', 'IH1', 'S'], 2)
# ('SHAMELLE', ['SH', 'AH0', 'M', 'EH1', 'L'], 2)
# ('ARVAD', ['AA0', 'R', 'V', 'AE1', 'D'], 2)
# ('THEREOF', ['DH', 'EH2', 'R', 'AH1', 'V'], 2)
# ('ENSLOW', ['IH0', 'N', 'S', 'L', 'OW1'], 2)
# ('MAKTOUMS', ['M', 'AE0', 'K', 'T', 'UW1', 'M', 'Z'], 2)
# ('ASHIS', ['AH0', 'SH', 'IY1', 'Z'], 2)
# ('CARAFE', ['K', 'AH0', 'R', 'AE1', 'F'], 2)
# ('PRETEEN', ['P', 'R', 'IY2', 'T', 'IY1', 'N'], 2)
# ('MARQUARD', ['M', 'AA0', 'R', 'K', 'W', 'AA1', 'R', 'D'], 2)
# ('JENNETTE', ['ZH', 'IH0', 'N', 'EH1', 'T'], 2)
# ('ENTHUSE', ['IH0', 'N', 'TH', 'UW1', 'Z'], 2)
# ('ACCEPTS', ['AE0', 'K', 'S', 'EH1', 'P', 'T', 'S'], 2)
# ('POPEIL', ['P', 'OW2', 'P', 'IY1', 'L'], 2)
# ('REMAINED', ['R', 'IH0', 'M', 'EY1', 'N', 'D'], 2)
# ('MATURED', ['M', 'AH0', 'T', 'Y', 'UH1', 'R', 'D'], 2)
# ('GARAGE', ['G', 'ER0', 'AA1', 'ZH'], 2)
# ('COLLAGE', ['K', 'AH0', 'L', 'AA1', 'ZH'], 2)
# ('POSTDATES', ['P', 'OW2', 'S', 'T', 'D', 'EY1', 'T', 'S'], 2)
# ('ABSCONDS', ['AE0', 'B', 'S', 'K', 'AA1', 'N', 'D', 'Z'], 2)
# ('MCQUINN', ['M', 'AH0', 'K', 'W', 'IH1', 'N'], 2)
# ('VARDON', ['V', 'AA0', 'R', 'D', 'AO1', 'N'], 2)
# ('REPAYS', ['R', 'IY2', 'P', 'EY1', 'Z'], 2)
# ('GABEL', ['G', 'AH0', 'B', 'EH1', 'L'], 2)
# ('ALONG', ['AH0', 'L', 'AO1', 'NG'], 2)
# ('FORECLOSE', ['F', 'AO0', 'R', 'K', 'L', 'OW1', 'Z'], 2)
# ('MONIQUE', ['M', 'OW2', 'N', 'IY1', 'K'], 2)
# ('PORTEND', ['P', 'AO0', 'R', 'T', 'EH1', 'N', 'D'], 2)
# ('CLINIQUE', ['K', 'L', 'AH0', 'N', 'IY1', 'K'], 2)
# ('DEJONGH', ['D', 'AH0', 'JH', 'AO1', 'NG'], 2)
# ('PAROLED', ['P', 'ER0', 'OW1', 'L', 'D'], 2)
# ('DEMURRED', ['D', 'IH0', 'M', 'ER1', 'D'], 2)
# ('CONSENTS', ['K', 'AH0', 'N', 'S', 'EH1', 'N', 'T', 'S'], 2)
# ('RAMPELL', ['R', 'AE0', 'M', 'P', 'EH1', 'L'], 2)
# ('VERTEL', ['V', 'ER2', 'T', 'EH1', 'L'], 2)
# ('PROTRACT', ['P', 'R', 'OW0', 'T', 'R', 'AE1', 'K', 'T'], 2)
# ('BEAUFRERE', ['B', 'OW2', 'F', 'R', 'EH1', 'R'], 2)
# ('FORGO', ['F', 'AO0', 'R', 'G', 'OW1'], 2)
# ('SURESH', ['S', 'ER0', 'EH1', 'SH'], 2)
# ('UDELLE', ['AH0', 'D', 'EH1', 'L'], 2)
# ('ASHCREEK', ['AE2', 'SH', 'K', 'R', 'IY1', 'K'], 2)
# ('CONDUCTS', ['K', 'AH0', 'N', 'D', 'AH1', 'K', 'T', 'S'], 2)
# ('BOITNOTT', ['B', 'OY0', 'T', 'N', 'AA1', 'T'], 2)
# ('VANDROSS', ['V', 'AE2', 'N', 'D', 'R', 'AO1', 'S'], 2)
# ('REFER', ['R', 'AH0', 'F', 'ER1'], 2)
# ('VAHID', ['V', 'AA0', 'HH', 'IY1', 'D'], 2)
# ('KHARTOUM', ['K', 'AA2', 'R', 'T', 'UW1', 'M'], 2)
# ('MORAIN', ['M', 'ER0', 'EY1', 'N'], 2)
# ('UNWED', ['AH0', 'N', 'W', 'EH1', 'D'], 2)
# ('MAEVE', ['M', 'AH0', 'EH1', 'V'], 2)
# ('EMERGED', ['IH0', 'M', 'ER1', 'JH', 'D'], 2)
# ('SACHET', ['S', 'AE0', 'SH', 'EY1'], 2)
# ('UNTIED', ['AH0', 'N', 'T', 'AY1', 'D'], 2)
# ('BEGETS', ['B', 'IH0', 'G', 'EH1', 'T', 'S'], 2)
# ('KRISTINE', ['K', 'R', 'IH0', 'S', 'T', 'IY1', 'N'], 2)
# ('DEVOLVE', ['D', 'IH0', 'V', 'AA1', 'L', 'V'], 2)
# ('GILCREASE', ['G', 'IH0', 'L', 'K', 'R', 'IY1', 'S'], 2)
# ('REGAINED', ['R', 'IY0', 'G', 'EY1', 'N', 'D'], 2)
# ('PREPARE', ['P', 'R', 'IY0', 'P', 'EH1', 'R'], 2)
# ('DAMOOSE', ['D', 'AH0', 'M', 'UW1', 'S'], 2)
# ('EXPRESS', ['IH0', 'K', 'S', 'P', 'R', 'EH1', 'S'], 2)
# ('RAJNEESH', ['R', 'AA0', 'JH', 'N', 'IY1', 'SH'], 2)
# ('CONDONE', ['K', 'AH0', 'N', 'D', 'OW1', 'N'], 2)
# ('SURPASS', ['S', 'ER0', 'P', 'AE1', 'S'], 2)
# ('SUBMERSED', ['S', 'AH0', 'B', 'M', 'ER1', 'S', 'T'], 2)
# ('BELOW', ['B', 'IH0', 'L', 'OW1'], 2)
# ('VONARX', ['V', 'AH0', 'N', 'AA1', 'R', 'K', 'S'], 2)
# ('PRETENDS', ['P', 'R', 'IY0', 'T', 'EH1', 'N', 'D', 'Z'], 2)
# ('FARIES', ['F', 'EH0', 'R', 'IY1', 'Z'], 2)
# ('ABORT', ['AH0', 'B', 'AO1', 'R', 'T'], 2)
# ('LAMAUR', ['L', 'AH0', 'M', 'AO1', 'R'], 2)
# ('WALEED', ['W', 'AA2', 'L', 'IY1', 'D'], 2)
# ('GODINE', ['G', 'OW0', 'D', 'IY1', 'N'], 2)
# ('PAYEUR', ['P', 'EY0', 'ER1'], 2)
# ('BINETTE', ['B', 'IH0', 'N', 'EH1', 'T'], 2)
# ('MORAYS', ['M', 'ER0', 'EY1', 'Z'], 2)
# ('ADO', ['AH0', 'D', 'UW1'], 2)
# ('CAMILLE', ['K', 'AH0', 'M', 'IY1', 'L'], 2)
# ('PURDUE', ['P', 'ER0', 'D', 'UW1'], 2)
# ('BURGOYNE', ['B', 'ER0', 'G', 'OY1', 'N'], 2)
# ('ILAN', ['IY2', 'L', 'AA1', 'N'], 2)
# ('BRUYETTE', ['B', 'R', 'UW0', 'EH1', 'T'], 2)
# ('MISPRICED', ['M', 'IH0', 'S', 'P', 'R', 'AY1', 'S', 'T'], 2)
# ('LIQUEURS', ['L', 'IH0', 'K', 'ER1', 'Z'], 2)
# ('INGRAINED', ['IH2', 'N', 'G', 'R', 'EY1', 'N', 'D'], 2)
# ('ADHERE', ['AH0', 'D', 'HH', 'IH1', 'R'], 2)
# ('ELAINE', ['IH0', 'L', 'EY1', 'N'], 2)
# ('VANHOOK', ['V', 'AE2', 'N', 'HH', 'UH1', 'K'], 2)
# ('BABOON', ['B', 'AH0', 'B', 'UW1', 'N'], 2)
# ('DUTIL', ['D', 'AH0', 'T', 'IH1', 'L'], 2)
# ('ABROAD', ['AH0', 'B', 'R', 'AO1', 'D'], 2)
# ('REVOKED', ['R', 'IH0', 'V', 'OW1', 'K', 'T'], 2)
# ('AMEND', ['AH0', 'M', 'EH1', 'N', 'D'], 2)
# ('REDEEMED', ['R', 'IH0', 'D', 'IY1', 'M', 'D'], 2)
# ('VIAU', ['V', 'IY0', 'OW1'], 2)
# ('TODAY', ['T', 'AH0', 'D', 'EY1'], 2)
# ('GODDAMN', ['G', 'AA2', 'D', 'AE1', 'M'], 2)
# ('MCCAUL', ['M', 'AH0', 'K', 'AO1', 'L'], 2)
# ('LABORDE', ['L', 'AH0', 'B', 'AO1', 'R', 'D'], 2)
# ('AKINS', ['AH0', 'K', 'IH1', 'N', 'Z'], 2)
# ('REJOICED', ['R', 'IH0', 'JH', 'OY1', 'S', 'T'], 2)
# ('MCMATH', ['M', 'AH0', 'K', 'M', 'AE1', 'TH'], 2)
# ('LUPONE', ['L', 'UW2', 'P', 'OW1', 'N'], 2)
# ('BRUSETT', ['B', 'R', 'UH0', 'S', 'EH1', 'T'], 2)
# ('TRANSFORMED', ['T', 'R', 'AE0', 'N', 'S', 'F', 'AO1', 'R', 'M', 'D'], 2)
# ('ROUSSELLE', ['R', 'UW2', 'S', 'EH1', 'L'], 2)
# ('BEMUSED', ['B', 'IH0', 'M', 'Y', 'UW1', 'Z', 'D'], 2)
# ('IMREG', ['IH2', 'M', 'R', 'EH1', 'G'], 2)
# ('REJECTS', ['R', 'IH0', 'JH', 'EH1', 'K', 'T', 'S'], 2)
# ('DISTRUST', ['D', 'IH0', 'S', 'T', 'R', 'AH1', 'S', 'T'], 2)
# ('PATROLS', ['P', 'AH0', 'T', 'R', 'OW1', 'L', 'Z'], 2)
# ('OBVERSE', ['AH0', 'B', 'V', 'ER1', 'S'], 2)
# ('GARONE', ['G', 'ER0', 'OW1', 'N'], 2)
# ('HEROUX', ['HH', 'ER0', 'UW1'], 2)
# ('IWAI', ['AY0', 'W', 'AY1'], 2)
# ('BARAFF', ['B', 'AA0', 'R', 'AA1', 'F'], 2)
# ('CREDEUR', ['K', 'R', 'IH0', 'D', 'ER1'], 2)
# ('CHENAULT', ['SH', 'IH0', 'N', 'OW1'], 2)
# ('SURCHARGE', ['S', 'ER0', 'CH', 'AA1', 'R', 'JH'], 2)
# ('CABAL', ['K', 'AH0', 'B', 'AA1', 'L'], 2)
# ('TRUSTEE', ['T', 'R', 'AH2', 'S', 'T', 'IY1'], 2)
# ('BRITOIL', ['B', 'R', 'IH0', 'T', 'OY1', 'L'], 2)
# ('HACHETTE', ['HH', 'AH0', 'SH', 'EH1', 'T'], 2)
# ('PRECOURT', ['P', 'R', 'IH0', 'K', 'AO1', 'R', 'T'], 2)
# ('RINTEL', ['R', 'IH0', 'N', 'T', 'EH1', 'L'], 2)
# ('IGNORE', ['IH2', 'G', 'N', 'AO1', 'R'], 2)
# ('ANNETT', ['AH0', 'N', 'EH1', 'T'], 2)
# ('BLOCKADE', ['B', 'L', 'AA2', 'K', 'EY1', 'D'], 2)
# ('RELEASE', ['R', 'IY0', 'L', 'IY1', 'S'], 2)
# ('VANEK', ['V', 'AE0', 'N', 'EH1', 'K'], 2)
# ('MELLOAN', ['M', 'EH0', 'L', 'OW1', 'N'], 2)
# ('LAMINNE', ['L', 'AH0', 'M', 'IH1', 'N'], 2)
# ('ENTHUSED', ['IH0', 'N', 'TH', 'UW1', 'Z', 'D'], 2)
# ('TRIOMPHE', ['T', 'R', 'IY0', 'OW1', 'M', 'F'], 2)
# ('CAILLOUET', ['K', 'EY2', 'L', 'UW1', 'T'], 2)
# ('SUZANNE', ['S', 'UW0', 'Z', 'AE1', 'N'], 2)
# ('NEVEAU', ['N', 'IH0', 'V', 'OW1'], 2)
# ('DEVEAUX', ['D', 'IH0', 'V', 'OW1'], 2)
# ('DEMUR', ['D', 'IH0', 'M', 'ER1'], 2)
# ('BEREAVE', ['B', 'ER0', 'IY1', 'V'], 2)
# ('BRUNETTES', ['B', 'R', 'UW0', 'N', 'EH1', 'T', 'S'], 2)
# ('ENCASED', ['EH0', 'N', 'K', 'EY1', 'S', 'T'], 2)
# ('FORGIVE', ['F', 'ER0', 'G', 'IH1', 'V'], 2)
# ('CONFIDES', ['K', 'AH0', 'N', 'F', 'AY1', 'D', 'Z'], 2)
# ('PRESCRIBES', ['P', 'R', 'IY0', 'S', 'K', 'R', 'AY1', 'B', 'Z'], 2)
# ('UNBOOK', ['AH0', 'N', 'B', 'UH1', 'K'], 2)
# ('TRANSLATE', ['T', 'R', 'AE0', 'N', 'Z', 'L', 'EY1', 'T'], 2)
# ('GUERTIN', ['G', 'ER2', 'T', 'IH1', 'N'], 2)
# ('MYRLENE', ['M', 'IH0', 'R', 'L', 'IY1', 'N'], 2)
# ('DISTIL', ['D', 'IH0', 'S', 'T', 'IH1', 'L'], 2)
# ('COLLAPSE', ['K', 'AH0', 'L', 'AE1', 'P', 'S'], 2)
# ('OUTPOURS', ['AW2', 'T', 'P', 'AO1', 'R', 'Z'], 2)
# ('ASSUME', ['AH0', 'S', 'UW1', 'M'], 2)
# ('DEVOSS', ['D', 'IH0', 'V', 'AA1', 'S'], 2)
# ('VANDALL', ['V', 'AE2', 'N', 'D', 'AO1', 'L'], 2)
# ('EMPLOYS', ['EH0', 'M', 'P', 'L', 'OY1', 'Z'], 2)
# ('IMPLODES', ['IH2', 'M', 'P', 'L', 'OW1', 'D', 'Z'], 2)
# ('SALAAM', ['S', 'AH0', 'L', 'AA1', 'M'], 2)
# ('LEMONT', ['L', 'AH0', 'M', 'AA1', 'N', 'T'], 2)
# ('TIRADE', ['T', 'AY0', 'R', 'EY1', 'D'], 2)
# ('REDRESS', ['R', 'IY0', 'D', 'R', 'EH1', 'S'], 2)
# ('VANTRAN', ['V', 'AE2', 'N', 'T', 'R', 'AE1', 'N'], 2)
# ('RASHEED', ['R', 'AH0', 'SH', 'IY1', 'D'], 2)
# ('DAHRAIN', ['D', 'AH0', 'R', 'EY1', 'N'], 2)
# ('MAUPIN', ['M', 'OW0', 'P', 'AE1', 'N'], 2)
# ('BELVOIR', ['B', 'EH0', 'L', 'V', 'W', 'AA1', 'R'], 2)
# ('SARETTE', ['S', 'ER0', 'EH1', 'T'], 2)
# ('MCCREIGHT', ['M', 'AH0', 'K', 'R', 'EY1', 'T'], 2)
# ('ALLUDE', ['AH0', 'L', 'UW1', 'D'], 2)
# ('BEQUEATH', ['B', 'IH0', 'K', 'W', 'IY1', 'TH'], 2)
# ('NORTHEAST', ['N', 'AO2', 'R', 'TH', 'IY1', 'S', 'T'], 2)
# ('EMERSED', ['IH0', 'M', 'ER1', 'S', 'T'], 2)
# ('DEVELLE', ['D', 'AH0', 'V', 'EH1', 'L'], 2)
# ('CHATEAU', ['SH', 'AE0', 'T', 'OW1'], 2)
# ('ATOP', ['AH0', 'T', 'AA1', 'P'], 2)
# ('MCCLURG', ['M', 'AH0', 'K', 'L', 'ER1', 'G'], 2)
# ('GERAIS', ['JH', 'ER0', 'EY1'], 2)
# ('JOBETE', ['JH', 'OW0', 'B', 'IY1', 'T'], 2)
# ('SICHUAN', ['S', 'IH2', 'CH', 'W', 'AA1', 'N'], 2)
# ('PARLETTE', ['P', 'AA2', 'R', 'L', 'EH1', 'T'], 2)
# ('MCKEY', ['M', 'AH0', 'K', 'IY1'], 2)
# ('OBTAIN', ['AH0', 'B', 'T', 'EY1', 'N'], 2)
# ('SANJIV', ['S', 'AA2', 'N', 'JH', 'IY1', 'V'], 2)
# ('GABON', ['G', 'AH0', 'B', 'AA1', 'N'], 2)
# ('PROLOG', ['P', 'R', 'OW0', 'L', 'AA1', 'G'], 2)
# ('EVONNE', ['EH2', 'V', 'AA1', 'N'], 2)
# ('SEDUCED', ['S', 'IH0', 'D', 'UW1', 'S', 'T'], 2)
# ('NAJIB', ['N', 'AH0', 'JH', 'IY1', 'B'], 2)
# ('BIO', ['B', 'AY2', 'OW1'], 2)
# ('GALLIEN', ['G', 'AH0', 'L', 'IY1', 'N'], 2)
# ('JUNETTE', ['JH', 'UW2', 'N', 'EH1', 'T'], 2)
# ('HORMEL', ['HH', 'AO0', 'R', 'M', 'EH1', 'L'], 2)
# ('COMMITS', ['K', 'AH0', 'M', 'IH1', 'T', 'S'], 2)
# ('BEFFA', ['B', 'IH2', 'F', 'AA1'], 2)
# ('REPELLED', ['R', 'AH0', 'P', 'EH1', 'L', 'D'], 2)
# ('EMBOSS', ['IH0', 'M', 'B', 'AO1', 'S'], 2)
# ('PREMARK', ['P', 'R', 'IY0', 'M', 'AA1', 'R', 'K'], 2)
# ('MCGANN', ['M', 'AH0', 'G', 'AE1', 'N'], 2)
# ('MARLEEN', ['M', 'AA0', 'R', 'L', 'IY1', 'N'], 2)
# ('SARRAJ', ['S', 'AA2', 'R', 'AY1'], 2)
# ('RAVINE', ['R', 'AH0', 'V', 'IY1', 'N'], 2)
# ('BABAR', ['B', 'AA2', 'B', 'AA1', 'R'], 2)
# ('INDUCED', ['IH2', 'N', 'D', 'UW1', 'S', 'T'], 2)
# ('DISPELS', ['D', 'IH0', 'S', 'P', 'EH1', 'L', 'Z'], 2)
# ('BUCKNELL', ['B', 'AH2', 'K', 'N', 'EH1', 'L'], 2)
# ('MISTAKES', ['M', 'IH0', 'S', 'T', 'EY1', 'K', 'S'], 2)
# ('VOYEUR', ['V', 'OY2', 'Y', 'UW1', 'R'], 2)
# ('GAUTREAU', ['G', 'OW0', 'T', 'R', 'OW1'], 2)
# ('PILOTTE', ['P', 'IH0', 'L', 'AO1', 'T'], 2)
# ('DEJEAN', ['D', 'IH0', 'ZH', 'IY1', 'N'], 2)
# ('PRETENSE', ['P', 'R', 'IY0', 'T', 'EH1', 'N', 'S'], 2)
# ('MCCRIGHT', ['M', 'AH0', 'K', 'R', 'AY1', 'T'], 2)
# ('BRAZEAU', ['B', 'R', 'AH0', 'Z', 'OW1'], 2)
# ('CONFUSE', ['K', 'AH0', 'N', 'F', 'Y', 'UW1', 'Z'], 2)
# ('NEMOURS', ['N', 'IH0', 'M', 'AO1', 'R', 'Z'], 2)
# ('NADEAU', ['N', 'AH0', 'D', 'OW1'], 2)
# ('DERANGE', ['D', 'IH0', 'R', 'EY1', 'N', 'JH'], 2)
# ('BEAUVAIS', ['B', 'OW0', 'V', 'EY1'], 2)
# ('PERMIT', ['P', 'ER0', 'M', 'IH1', 'T'], 2)
# ('CHEVETTE', ['SH', 'AH0', 'V', 'EH1', 'T'], 2)
# ('LAMENTS', ['L', 'AH0', 'M', 'EH1', 'N', 'T', 'S'], 2)
# ('VIGNETTES', ['V', 'IH0', 'N', 'Y', 'EH1', 'T', 'S'], 2)
# ('MCNAY', ['M', 'AH0', 'K', 'N', 'EY1'], 2)
# ('REMOLD', ['R', 'IY0', 'M', 'OW1', 'L', 'D'], 2)
# ('RABOURN', ['R', 'AH0', 'B', 'UH1', 'R', 'N'], 2)
# ('UNLINED', ['AH0', 'N', 'L', 'AY1', 'N', 'D'], 2)
# ('COMPRISE', ['K', 'AH0', 'M', 'P', 'R', 'AY1', 'Z'], 2)
# ('COLLECT', ['K', 'AH0', 'L', 'EH1', 'K', 'T'], 2)
# ('RODIME', ['R', 'OW0', 'D', 'IY1', 'M'], 2)
# ('LAVERGNE', ['L', 'AH0', 'V', 'ER1', 'N', 'Y'], 2)
# ('FRANCAISE', ['F', 'R', 'AA0', 'N', 'S', 'EH1', 'Z'], 2)
# ('CAHOOTS', ['K', 'AH0', 'HH', 'UW1', 'T', 'S'], 2)
# ('OPINE', ['OW0', 'P', 'AY1', 'N'], 2)
# ('GAUDETTE', ['G', 'OW0', 'D', 'EH1', 'T'], 2)
# ('GEORGETTE', ['JH', 'AO0', 'R', 'JH', 'EH1', 'T'], 2)
# ('REDO', ['R', 'IY0', 'D', 'UW1'], 2)
# ('EXUM', ['IH0', 'G', 'Z', 'AH1', 'M'], 2)
# ('RADBOURNE', ['R', 'AH0', 'D', 'B', 'UH1', 'R', 'N'], 2)
# ('DETRACT', ['D', 'IH0', 'T', 'R', 'AE1', 'K', 'T'], 2)
# ('ACHIEVE', ['AH0', 'CH', 'IY1', 'V'], 2)
# ('MISPRICE', ['M', 'IH0', 'S', 'P', 'R', 'AY1', 'S'], 2)
# ('DONAIS', ['D', 'AH0', 'N', 'EY1'], 2)
# ('ENSURE', ['EH0', 'N', 'SH', 'UH1', 'R'], 2)
# ('BEHOOVE', ['B', 'IH0', 'HH', 'UW1', 'V'], 2)
# ('CORRON', ['K', 'ER0', 'AO1', 'N'], 2)
# ('SHENYANG', ['SH', 'EH0', 'N', 'Y', 'AE1', 'NG'], 2)
# ('DUET', ['D', 'UW0', 'EH1', 'T'], 2)
# ('EXCEEDS', ['IH0', 'K', 'S', 'IY1', 'D', 'Z'], 2)
# ('BASHAR', ['B', 'AH0', 'SH', 'AA1', 'R'], 2)
# ('DURRANT', ['D', 'UH0', 'R', 'AE1', 'N', 'T'], 2)
# ('MCNEESE', ['M', 'AH0', 'K', 'N', 'IY1', 'S'], 2)
# ('MISCHARGED', ['M', 'IH0', 'S', 'CH', 'AA1', 'R', 'JH', 'D'], 2)
# ('ANNOYS', ['AH0', 'N', 'OY1', 'Z'], 2)
# ('SUPPRESSED', ['S', 'AH0', 'P', 'R', 'EH1', 'S', 'T'], 2)
# ('CLARICE', ['K', 'L', 'ER0', 'IY1', 'S'], 2)
# ('BARBETTE', ['B', 'AA0', 'R', 'B', 'EH1', 'T'], 2)
# ('BEYOND', ['B', 'IH0', 'AA1', 'N', 'D'], 2)
# ('MALVEAUX', ['M', 'AE0', 'L', 'V', 'OW1'], 2)
# ('DHAHRAN', ['D', 'AH0', 'R', 'AA1', 'N'], 2)
# ('DEBOE', ['D', 'IH0', 'B', 'OW1'], 2)
# ('UNEARNED', ['AH0', 'N', 'ER1', 'N', 'D'], 2)
# ('LORGNETTE', ['L', 'AO0', 'R', 'N', 'Y', 'EH1', 'T'], 2)
# ('UNVEILS', ['AH0', 'N', 'V', 'EY1', 'L', 'Z'], 2)
# ('ADORN', ['AH0', 'D', 'AO1', 'R', 'N'], 2)
# ('CAHOOT', ['K', 'AH0', 'HH', 'UW1', 'T'], 2)
# ('BOZTEPE', ['B', 'AA0', 'Z', 'T', 'EH1', 'P'], 2)
# ('TAMIL', ['T', 'AH0', 'M', 'IH1', 'L'], 2)
# ('UNWIND', ['AH0', 'N', 'W', 'AY1', 'N', 'D'], 2)
# ('DORETTE', ['D', 'ER0', 'EH1', 'T'], 2)
# ('AGGRIEVE', ['AH0', 'G', 'R', 'IY1', 'V'], 2)
# ('AGLOW', ['AH0', 'G', 'L', 'OW1'], 2)
# ('RECITES', ['R', 'IY0', 'S', 'AY1', 'T', 'S'], 2)
# ('XUEDONG', ['Z', 'UW0', 'D', 'AO1', 'NG'], 2)
# ('INVOKED', ['IH2', 'N', 'V', 'OW1', 'K', 'T'], 2)
# ('CHAMPAGNE', ['SH', 'AE0', 'M', 'P', 'EY1', 'N'], 2)
# ('CAROUSE', ['K', 'ER0', 'AW1', 'Z'], 2)
# ('MCTEER', ['M', 'AH0', 'K', 'T', 'IH1', 'R'], 2)
# ('FIFTEEN', ['F', 'IH0', 'F', 'T', 'IY1', 'N'], 2)
# ('DEDEAUX', ['D', 'IH0', 'D', 'OW1'], 2)
# ('SUSANNE', ['S', 'UW2', 'Z', 'AE1', 'N'], 2)
# ('EXCLAIMS', ['IH0', 'K', 'S', 'K', 'L', 'EY1', 'M', 'Z'], 2)
# ('TRUFFAUT', ['T', 'R', 'UW0', 'F', 'OW1'], 2)
# ('DILATE', ['D', 'AY2', 'L', 'EY1', 'T'], 2)
# ('MANETTE', ['M', 'AH0', 'N', 'EH1', 'T'], 2)
# ('CHASTEEN', ['CH', 'AH0', 'S', 'T', 'IY1', 'N'], 2)
# ('ADEPT', ['AH0', 'D', 'EH1', 'P', 'T'], 2)
# ('MARZETTE', ['M', 'AA2', 'R', 'Z', 'EH1', 'T'], 2)
# ('MCGAW', ['M', 'AH0', 'G', 'AO1'], 2)
# ('GOULET', ['G', 'UW0', 'L', 'EH1', 'T'], 2)
# ('BATONS', ['B', 'AE0', 'T', 'AA1', 'N', 'Z'], 2)
# ('DUNNO', ['D', 'AH0', 'N', 'OW1'], 2)
# ('SLOVENE', ['S', 'L', 'OW2', 'V', 'IY1', 'N'], 2)
# ('MONTEL', ['M', 'AA0', 'N', 'T', 'EH1', 'L'], 2)
# ('DEVALL', ['D', 'EY0', 'V', 'AA1', 'L'], 2)
# ('BEIJING', ['B', 'EY2', 'ZH', 'IH1', 'NG'], 2)
# ('HISSELF', ['HH', 'IH2', 'S', 'EH1', 'L', 'F'], 2)
# ('UNCORKS', ['AH0', 'N', 'K', 'AO1', 'R', 'K', 'S'], 2)
# ('MCLANE', ['M', 'AH0', 'K', 'L', 'EY1', 'N'], 2)
# ('DIOR', ['D', 'IY2', 'AO1', 'R'], 2)
# ('RESELL', ['R', 'IY0', 'S', 'EH1', 'L'], 2)
# ('URBAIN', ['ER0', 'B', 'EY1', 'N'], 2)
# ('SCORTESE', ['S', 'K', 'AO0', 'R', 'T', 'IY1', 'Z'], 2)
# ('BEHIND', ['B', 'IH0', 'HH', 'AY1', 'N', 'D'], 2)
# ('REVIVE', ['R', 'IH0', 'V', 'AY1', 'V'], 2)
# ('CHESNUTT', ['SH', 'IH0', 'S', 'N', 'AH1', 'T'], 2)
# ('PLATOON', ['P', 'L', 'AH0', 'T', 'UW1', 'N'], 2)
# ('MACIAG', ['M', 'AH0', 'K', 'EY1', 'G'], 2)
# ('MARKESE', ['M', 'AA0', 'R', 'K', 'IY1', 'S'], 2)
# ('TABAR', ['T', 'AA0', 'B', 'AA1', 'R'], 2)
# ('UNTOLD', ['AH0', 'N', 'T', 'OW1', 'L', 'D'], 2)
# ('DEPOSE', ['D', 'IH0', 'P', 'OW1', 'Z'], 2)
# ('PICONE', ['P', 'IH0', 'K', 'OW1', 'N'], 2)
# ('FORBAD', ['F', 'ER0', 'B', 'AE1', 'D'], 2)
# ('SEDUCE', ['S', 'IH0', 'D', 'UW1', 'S'], 2)
# ('DEBUNK', ['D', 'IH0', 'B', 'AH1', 'NG', 'K'], 2)
# ('CATTELL', ['K', 'AH0', 'T', 'EH1', 'L'], 2)
# ('KACHUCK', ['K', 'AH0', 'CH', 'AH1', 'K'], 2)
# ('ADDRESSED', ['AH0', 'D', 'R', 'EH1', 'S', 'T'], 2)
# ('MCLEOD', ['M', 'AH0', 'K', 'L', 'AW1', 'D'], 2)
# ('TRIVETTE', ['T', 'R', 'IH0', 'V', 'EH1', 'T'], 2)
# ('PANCHEN', ['P', 'AA2', 'N', 'CH', 'EH1', 'N'], 2)
# ('MCHARGUE', ['M', 'AH0', 'K', 'AA1', 'R', 'G'], 2)
# ('MCSHAN', ['M', 'AH0', 'K', 'SH', 'AE1', 'N'], 2)
# ('INSURE', ['IH2', 'N', 'SH', 'UH1', 'R'], 2)
# ('MCBEATH', ['M', 'AH0', 'K', 'B', 'EH1', 'TH'], 2)
# ('DEBLANC', ['D', 'IH0', 'B', 'L', 'AE1', 'NG', 'K'], 2)
# ('EMIT', ['IH0', 'M', 'IH1', 'T'], 2)
# ('BEAGAN', ['B', 'AH0', 'G', 'AE1', 'N'], 2)
# ('DEBARR', ['D', 'IH0', 'B', 'AE1', 'R'], 2)
# ('PERFORCE', ['P', 'ER0', 'F', 'AO1', 'R', 'S'], 2)
# ('GEURIN', ['ZH', 'ER0', 'AE1', 'N'], 2)
# ('LAFORGE', ['L', 'AA0', 'F', 'AO1', 'R', 'G'], 2)
# ('ORTEZ', ['AO0', 'R', 'T', 'EH1', 'Z'], 2)
# ('TATTOO', ['T', 'AE2', 'T', 'UW1'], 2)
# ('RESUMED', ['R', 'IH0', 'Z', 'UW1', 'M', 'D'], 2)
# ('FINESSE', ['F', 'IH0', 'N', 'EH1', 'S'], 2)
# ('FORBESS', ['F', 'AO0', 'R', 'B', 'EH1', 'S'], 2)
# ('DISTILLS', ['D', 'IH0', 'S', 'T', 'IH1', 'L', 'Z'], 2)
# ('MCHALE', ['M', 'AH0', 'K', 'EY1', 'L'], 2)
# ('BELLEAU', ['B', 'IH0', 'L', 'OW1'], 2)
# ('REWARDS', ['R', 'IH0', 'W', 'AO1', 'R', 'D', 'Z'], 2)
# ('FORBADE', ['F', 'ER0', 'B', 'EY1', 'D'], 2)
# ('BUSLOAD', ['B', 'AH0', 'S', 'L', 'OW1', 'D'], 2)
# ('BADOUR', ['B', 'AH0', 'D', 'UH1', 'R'], 2)
# ('SWISSAIR', ['S', 'W', 'IH0', 'S', 'EH1', 'R'], 2)
# ('ELGA', ['IH0', 'L', 'G', 'AA1'], 2)
# ('RETOOL', ['R', 'IY0', 'T', 'UW1', 'L'], 2)
# ('DEKLERK', ['D', 'AH0', 'K', 'L', 'ER1', 'K'], 2)
# ('BADEAUX', ['B', 'AH0', 'D', 'OW1'], 2)
# ('BEMUSE', ['B', 'IH0', 'M', 'Y', 'UW1', 'Z'], 2)
# ('ENSNARE', ['IH0', 'N', 'S', 'N', 'EH1', 'R'], 2)
# ('ADORNS', ['AH0', 'D', 'AO1', 'R', 'N', 'Z'], 2)
# ('DUIGNAN', ['D', 'IH0', 'G', 'N', 'AE1', 'N'], 2)
# ('MCCAIN', ['M', 'AH0', 'K', 'EY1', 'N'], 2)
# ('DECLINE', ['D', 'IH0', 'K', 'L', 'AY1', 'N'], 2)
# ('AMUCK', ['AH0', 'M', 'AH1', 'K'], 2)
# ('CLARETTE', ['K', 'L', 'ER0', 'EH1', 'T'], 2)
# ('CANEZ', ['K', 'AA0', 'N', 'EH1', 'Z'], 2)
# ('MOQUIN', ['M', 'OW0', 'K', 'W', 'IY1', 'N'], 2)
# ('SUGGESTS', ['S', 'AH0', 'JH', 'EH1', 'S', 'T', 'S'], 2)
# ('ALERT', ['AH0', 'L', 'ER1', 'T'], 2)
# ('RECOILED', ['R', 'IY0', 'K', 'OY1', 'L', 'D'], 2)
# ('RECOILS', ['R', 'IY0', 'K', 'OY1', 'L', 'Z'], 2)
# ('TEHRANS', ['T', 'EY2', 'R', 'AA1', 'N', 'Z'], 2)
# ('UNMATCHED', ['AH0', 'N', 'M', 'AE1', 'CH', 'T'], 2)
# ('DECOOK', ['D', 'EH0', 'K', 'UH1', 'K'], 2)
# ('AZHAR', ['AH0', 'Z', 'AA1', 'R'], 2)
# ('GOULETTE', ['G', 'UW2', 'L', 'EH1', 'T'], 2)
# ('SUBSCRIBES', ['S', 'AH0', 'B', 'S', 'K', 'R', 'AY1', 'B', 'Z'], 2)
# ('MILAN', ['M', 'AH0', 'L', 'AA1', 'N'], 2)
# ('COMMEND', ['K', 'AH0', 'M', 'EH1', 'N', 'D'], 2)
# ('ELOPE', ['IH0', 'L', 'OW1', 'P'], 2)
# ('DEVOUT', ['D', 'IH0', 'V', 'AW1', 'T'], 2)
# ('MCLEES', ['M', 'AH0', 'K', 'L', 'IY1', 'Z'], 2)
# ('BERNARDS', ['B', 'ER0', 'N', 'AA1', 'R', 'D', 'Z'], 2)
# ('OPINES', ['OW0', 'P', 'AY1', 'N', 'Z'], 2)
# ('UNRING', ['AH0', 'N', 'R', 'IH1', 'NG'], 2)
# ('ROZELLE', ['R', 'AH0', 'Z', 'EH1', 'L'], 2)
# ('REESJONES', ['R', 'IY2', 'S', 'JH', 'OW1', 'N', 'Z'], 2)
# ('RESUME', ['R', 'IH0', 'Z', 'UW1', 'M'], 2)
# ('CONJOINED', ['K', 'AA2', 'N', 'JH', 'OY1', 'N', 'D'], 2)
# ('ESQUER', ['IH0', 'S', 'K', 'ER1'], 2)
# ('BECHTEL', ['B', 'EH2', 'K', 'T', 'EH1', 'L'], 2)
# ('BOWDOIN', ['B', 'OW0', 'D', 'OY1', 'N'], 2)
# ('MCKNEW', ['M', 'AH0', 'K', 'N', 'UW1'], 2)
# ('FRECHETTE', ['F', 'R', 'IH0', 'SH', 'EH1', 'T'], 2)
# ('MILLAY', ['M', 'IH0', 'L', 'EY1'], 2)
# ('IMPLIED', ['IH2', 'M', 'P', 'L', 'AY1', 'D'], 2)
# ('SARDINES', ['S', 'AA0', 'R', 'D', 'IY1', 'N', 'Z'], 2)
# ('TOKARS', ['T', 'OW0', 'K', 'AA1', 'R', 'Z'], 2)
# ('MCCREE', ['M', 'AH0', 'K', 'R', 'IY1'], 2)
# ('PREVENT', ['P', 'R', 'IH0', 'V', 'EH1', 'N', 'T'], 2)
# ('HURTEAU', ['HH', 'ER0', 'T', 'OW1'], 2)
# ('PROPEL', ['P', 'R', 'AH0', 'P', 'EH1', 'L'], 2)
# ('TORAN', ['T', 'AO0', 'R', 'AA1', 'N'], 2)
# ('CHAMPOUX', ['SH', 'AE0', 'M', 'P', 'UW1'], 2)
# ('BASSETTE', ['B', 'AH0', 'S', 'EH1', 'T'], 2)
# ('CAREERS', ['K', 'ER0', 'IH1', 'R', 'Z'], 2)
# ('PREDICTS', ['P', 'R', 'IH0', 'D', 'IH1', 'K', 'T', 'S'], 2)
# ('AFFORD', ['AH0', 'F', 'AO1', 'R', 'D'], 2)
# ('PUREE', ['P', 'Y', 'UH0', 'R', 'EY1'], 2)
# ('OKEEFE', ['OW0', 'K', 'IY1', 'F'], 2)
# ('KABRAL', ['K', 'AH0', 'B', 'R', 'AA1', 'L'], 2)
# ('PROLONGED', ['P', 'R', 'AH0', 'L', 'AO1', 'NG', 'D'], 2)
# ('GOOSTREE', ['G', 'UW0', 'S', 'T', 'R', 'IY1'], 2)
# ('QUESNELL', ['K', 'W', 'EY0', 'S', 'N', 'EY1', 'L'], 2)
# ('EXACTS', ['IH0', 'G', 'Z', 'AE1', 'K', 'T', 'S'], 2)
# ('REFILE', ['R', 'IY0', 'F', 'AY1', 'L'], 2)
# ('IGOR', ['IH2', 'G', 'AO1', 'R'], 2)
# ('IMMENSE', ['IH2', 'M', 'EH1', 'N', 'S'], 2)
# ('BORRELL', ['B', 'AO0', 'R', 'EY1', 'L'], 2)
# ('SCIMONE', ['S', 'IH0', 'M', 'OW1', 'N'], 2)
# ('RIYALS', ['R', 'IY0', 'Y', 'AA1', 'L', 'Z'], 2)
# ('LABORE', ['L', 'AH0', 'B', 'AO1', 'R'], 2)
# ('BEFELL', ['B', 'IH0', 'F', 'EH1', 'L'], 2)
# ('RANTOUL', ['R', 'AE2', 'N', 'T', 'UW1', 'L'], 2)
# ('GENDREAU', ['ZH', 'IH0', 'N', 'D', 'R', 'OW1'], 2)
# ('DESCHAINE', ['D', 'IH0', 'S', 'K', 'EY1', 'N'], 2)
# ('REVEAL', ['R', 'IH0', 'V', 'IY1', 'L'], 2)
# ('POLLUTES', ['P', 'AH0', 'L', 'UW1', 'T', 'S'], 2)
# ('MCCUEN', ['M', 'AH0', 'K', 'Y', 'UW1', 'N'], 2)
# ('ASKEY', ['AH0', 'S', 'K', 'IY1'], 2)
# ('INFUSED', ['IH2', 'N', 'F', 'Y', 'UW1', 'Z', 'D'], 2)
# ('PICHETTE', ['P', 'AH0', 'SH', 'EH1', 'T'], 2)
# ('NATWEST', ['N', 'AE2', 'T', 'W', 'EH1', 'S', 'T'], 2)
# ('DISCLAIM', ['D', 'IH0', 'S', 'K', 'L', 'EY1', 'M'], 2)
# ('ALARMS', ['AH0', 'L', 'AA1', 'R', 'M', 'Z'], 2)
# ('DISMAYS', ['D', 'IH0', 'S', 'M', 'EY1', 'Z'], 2)
# ('CARONE', ['K', 'ER0', 'OW1', 'N'], 2)
# ('DENEUVE', ['D', 'IH0', 'N', 'AH1', 'V'], 2)
# ('FOREWARNS', ['F', 'AO0', 'R', 'W', 'AO1', 'R', 'N', 'Z'], 2)
# ('KARUN', ['K', 'ER0', 'UW1', 'N'], 2)
# ('MCCLEESE', ['M', 'AH0', 'K', 'L', 'IY1', 'S'], 2)
# ('AFOOT', ['AH0', 'F', 'UH1', 'T'], 2)
# ('CAUDELL', ['K', 'OW0', 'D', 'EH1', 'L'], 2)
# ('SCORSESE', ['S', 'K', 'AO2', 'R', 'S', 'IY1', 'Z'], 2)
# ('REWORKED', ['R', 'IY0', 'W', 'ER1', 'K', 'T'], 2)
# ('JOETTE', ['ZH', 'OW0', 'EH1', 'T'], 2)
# ('PATASSE', ['P', 'AA2', 'T', 'AA1', 'S'], 2)
# ('IMPEND', ['IH2', 'M', 'P', 'EH1', 'N', 'D'], 2)
# ('QIRYAT', ['K', 'IH0', 'R', 'Y', 'AA1', 'T'], 2)
# ('MASONE', ['M', 'AH0', 'S', 'OW1', 'N'], 2)
# ('APPEND', ['AH0', 'P', 'EH1', 'N', 'D'], 2)
# ('UNFOLDS', ['AH0', 'N', 'F', 'OW1', 'L', 'D', 'Z'], 2)
# ('PROCURE', ['P', 'R', 'OW0', 'K', 'Y', 'UH1', 'R'], 2)
# ('DEPAUW', ['D', 'AH0', 'P', 'AW1'], 2)
# ('MCGRAIL', ['M', 'AH0', 'G', 'R', 'EY1', 'L'], 2)
# ('ENGWALL', ['IH0', 'NG', 'G', 'W', 'AO1', 'L'], 2)
# ('PILAF', ['P', 'IY2', 'L', 'AA1', 'F'], 2)
# ('DESTROYED', ['D', 'IH0', 'S', 'T', 'R', 'OY1', 'D'], 2)
# ('DURETTE', ['D', 'ER0', 'EH1', 'T'], 2)
# ('RESOLVED', ['R', 'IY0', 'Z', 'AA1', 'L', 'V', 'D'], 2)
# ('OBAR', ['AH0', 'B', 'AA1', 'R'], 2)
# ('VAZQUEZ', ['V', 'AE0', 'S', 'K', 'EH1', 'Z'], 2)
# ('MCBAIN', ['M', 'AH0', 'K', 'B', 'EY1', 'N'], 2)
# ('COMMODE', ['K', 'AH0', 'M', 'OW1', 'D'], 2)
# ('ELKIN', ['IH0', 'L', 'K', 'IH1', 'N'], 2)
# ('BOUQUETS', ['B', 'OW0', 'K', 'EY1', 'Z'], 2)
# ('SEGALL', ['S', 'EY0', 'G', 'AA1', 'L'], 2)
# ('EXPOSE', ['IH0', 'K', 'S', 'P', 'OW1', 'Z'], 2)
# ('CHAMBLESS', ['SH', 'AH0', 'M', 'B', 'L', 'IY1', 'S'], 2)
# ('DELAYED', ['D', 'IH0', 'L', 'EY1', 'D'], 2)
# ('LEONE', ['L', 'IY0', 'OW1', 'N'], 2)
# ('ABSTAIN', ['AH0', 'B', 'S', 'T', 'EY1', 'N'], 2)
# ('PRIMEAUX', ['P', 'R', 'IH0', 'M', 'OW1'], 2)
# ('RAHIM', ['R', 'AH0', 'HH', 'IY1', 'M'], 2)
# ('RELIEVES', ['R', 'IY0', 'L', 'IY1', 'V', 'Z'], 2)
# ('MCNEER', ['M', 'AH0', 'K', 'N', 'IH1', 'R'], 2)
# ('REBIRTHS', ['R', 'IY0', 'B', 'ER1', 'TH', 'S'], 2)
# ('UPON', ['AH0', 'P', 'AA1', 'N'], 2)
# ('ARNAUD', ['AA0', 'R', 'N', 'OW1'], 2)
# ('ESPOUSED', ['IH0', 'S', 'P', 'AW1', 'Z', 'D'], 2)
# ('DILBERT', ['D', 'IH0', 'L', 'B', 'ER1', 'T'], 2)
# ('ARNETTE', ['AA0', 'R', 'N', 'EH1', 'T'], 2)
# ('ARAU', ['AH0', 'R', 'AW1'], 2)
# ('UNKNOWN', ['AH0', 'N', 'N', 'OW1', 'N'], 2)
# ('ALGIERS', ['AE0', 'L', 'JH', 'IH1', 'R', 'Z'], 2)
# ('INSPECT', ['IH2', 'N', 'S', 'P', 'EH1', 'K', 'T'], 2)
# ('ABEE', ['AH0', 'B', 'IY1'], 2)
# ('BEAULIEU', ['B', 'OW2', 'L', 'Y', 'UH1'], 2)
# ('CHINESE', ['CH', 'AY0', 'N', 'IY1', 'Z'], 2)
# ('RELIES', ['R', 'IH0', 'L', 'AY1', 'Z'], 2)
# ('EILEEN', ['AY0', 'L', 'IY1', 'N'], 2)
# ('BEAUDOIN', ['B', 'OW0', 'D', 'OY1', 'N'], 2)
# ('MISPLACE', ['M', 'IH0', 'S', 'P', 'L', 'EY1', 'S'], 2)
# ('MCGEE', ['M', 'AH0', 'G', 'IY1'], 2)
# ('DISPLEASE', ['D', 'IH0', 'S', 'P', 'L', 'IY1', 'Z'], 2)
# ('DAKAR', ['D', 'AA0', 'K', 'AA1', 'R'], 2)
# ('MCGLYNN', ['M', 'AH0', 'G', 'L', 'IH1', 'N'], 2)
# ('EXPLAIN', ['IH0', 'K', 'S', 'P', 'L', 'EY1', 'N'], 2)
# ('LEHANE', ['L', 'AH0', 'HH', 'EY1', 'N'], 2)
# ('PICOULT', ['P', 'IH0', 'K', 'OW1', 'L', 'T'], 2)
# ('BIZET', ['B', 'IH0', 'Z', 'EH1', 'T'], 2)
# ('VALLEZ', ['V', 'AA0', 'L', 'EH1', 'Z'], 2)
# ('GIGNOUX', ['G', 'IH0', 'N', 'UW1'], 2)
# ('BATOR', ['B', 'AA0', 'T', 'AO1', 'R'], 2)
# ('MCGINNES', ['M', 'AH0', 'G', 'IH1', 'N', 'Z'], 2)
# ('OVERT', ['OW0', 'V', 'ER1', 'T'], 2)
# ('IMPALES', ['IH2', 'M', 'P', 'EY1', 'L', 'Z'], 2)
# ('AHOLDS', ['AH0', 'HH', 'OW1', 'L', 'D', 'Z'], 2)
# ('PRELIM', ['P', 'R', 'IH0', 'L', 'IH1', 'M'], 2)
# ('LAMBASTES', ['L', 'AE2', 'M', 'B', 'AE1', 'S', 'T', 'S'], 2)
# ('YIPPEE', ['Y', 'IH2', 'P', 'IY1'], 2)
# ('ALAIR', ['AH0', 'L', 'EH1', 'R'], 2)
# ('UNLOCKED', ['AH0', 'N', 'L', 'AA1', 'K', 'T'], 2)
# ('LAROQUE', ['L', 'ER0', 'OW1', 'K'], 2)
# ('MAJETTE', ['M', 'AH0', 'ZH', 'EH1', 'T'], 2)
# ('DETHRONED', ['D', 'IH0', 'TH', 'R', 'OW1', 'N', 'D'], 2)
# ('ENCASE', ['EH0', 'N', 'K', 'EY1', 'S'], 2)
# ('COSTUMES', ['K', 'AA0', 'S', 'T', 'UW1', 'M', 'Z'], 2)
# ('TULANE', ['T', 'UW0', 'L', 'EY1', 'N'], 2)
# ('PIERETTE', ['P', 'IH0', 'R', 'EH1', 'T'], 2)
# ('REMOVED', ['R', 'IY0', 'M', 'UW1', 'V', 'D'], 2)
# ('DEKALB', ['D', 'IH0', 'K', 'AE1', 'L', 'B'], 2)
# ('ADORE', ['AH0', 'D', 'AO1', 'R'], 2)
# ('ACQUAINT', ['AH0', 'K', 'W', 'EY1', 'N', 'T'], 2)
# ('BALDUR', ['B', 'AA0', 'L', 'D', 'UH1', 'R'], 2)
# ('DEPICTS', ['D', 'IH0', 'P', 'IH1', 'K', 'T', 'S'], 2)
# ('SHARLEEN', ['SH', 'AA0', 'R', 'L', 'IY1', 'N'], 2)
# ('LAVELLE', ['L', 'AH0', 'V', 'EH1', 'L'], 2)
# ('ANNETTE', ['AH0', 'N', 'EH1', 'T'], 2)
# ('DECLERCQ', ['D', 'AH0', 'K', 'L', 'ER1', 'K'], 2)
# ('BESET', ['B', 'IH0', 'S', 'EH1', 'T'], 2)
# ('ARIS', ['ER0', 'IY1', 'S'], 2)
# ('GERMANE', ['JH', 'ER0', 'M', 'EY1', 'N'], 2)
# ('NOVELL', ['N', 'OW0', 'V', 'EH1', 'L'], 2)
# ('GEORGINE', ['JH', 'AO2', 'R', 'JH', 'IY1', 'N'], 2)
# ('ATTACKED', ['AH0', 'T', 'AE1', 'K', 'T'], 2)
# ('AGAPE', ['AH0', 'G', 'EY1', 'P'], 2)
# ('HAVILL', ['HH', 'AA0', 'V', 'IY1', 'L'], 2)
# ('SUBSCRIBE', ['S', 'AH0', 'B', 'S', 'K', 'R', 'AY1', 'B'], 2)
# ('DEPRESSED', ['D', 'IH0', 'P', 'R', 'EH1', 'S', 'T'], 2)
# ('MISTREAT', ['M', 'IH0', 'S', 'T', 'R', 'IY1', 'T'], 2)
# ('VARIN', ['V', 'AA0', 'R', 'IY1', 'N'], 2)
# ('MOUEIX', ['M', 'UW2', 'W', 'AY1', 'K', 'S'], 2)
# ('PAYEE', ['P', 'EY2', 'IY1'], 2)
# ('MASOUD', ['M', 'AH0', 'S', 'UW1', 'D'], 2)
# ('RENOIRS', ['R', 'EH0', 'N', 'W', 'AA1', 'R', 'Z'], 2)
# ...
#  ('BUCKLING', ['B', 'AH1', 'K', 'L', 'IH0', 'NG'], 1),
#  ('ARMAND', ['AA1', 'R', 'M', 'AA0', 'N', 'D'], 1),
#  ('ONBOARD', ['AA1', 'N', 'B', 'AO2', 'R', 'D'], 1),
#  ('MOEHRING', ['M', 'AO1', 'R', 'IH0', 'NG'], 1),
#  ('DAVIDGE', ['D', 'AE1', 'V', 'IH0', 'JH'], 1),
#  ('NITRIDE', ['N', 'AY1', 'T', 'R', 'AY0', 'D'], 1),
#  ('MISSES', ['M', 'IH1', 'S', 'IH0', 'Z'], 1),
#  ('EDGY', ['EH1', 'JH', 'IY0'], 1),
#  ('TETERS', ['T', 'IY1', 'T', 'ER0', 'Z'], 1),
#  ('PLUNGER', ['P', 'L', 'AH1', 'N', 'JH', 'ER0'], 1),
#  ('COMICS', ['K', 'AA1', 'M', 'IH0', 'K', 'S'], 1),
#  ('ADJUDGED', ['AH0', 'JH', 'AH1', 'JH', 'D'], 2),
#  ('BOUWENS', ['B', 'AW1', 'AH0', 'N', 'Z'], 1),
#  ('GUNNERS', ['G', 'AH1', 'N', 'ER0', 'Z'], 1),
#  ('ROLLINGS', ['R', 'OW1', 'L', 'IH0', 'NG', 'Z'], 1),
#  ('EWTON', ['Y', 'UW1', 'T', 'AH0', 'N'], 1),
#  ('ROHER', ['R', 'OW1', 'ER0'], 1),
#  ('CUTTY', ['K', 'AH1', 'T', 'IY0'], 1),
#  ('MONCUS', ['M', 'AA1', 'N', 'K', 'IH0', 'S'], 1),
#  ('SCHALOW', ['SH', 'AE1', 'L', 'OW0'], 1),
#  ('CHAUFFEURS', ['SH', 'OW0', 'F', 'ER1', 'Z'], 2),
#  ('DIGEST', ['D', 'AY0', 'JH', 'EH1', 'S', 'T'], 2),
#  ('NORTHCLIFF', ['N', 'AO1', 'R', 'TH', 'K', 'L', 'IH0', 'F'], 1),
#  ('RINGLAND', ['R', 'IH1', 'NG', 'G', 'L', 'AH0', 'N', 'D'], 1),
#  ('POSNER', ['P', 'OW1', 'Z', 'N', 'ER0'], 1),
#  ('BRACELET', ['B', 'R', 'EY1', 'S', 'L', 'AH0', 'T'], 1),
#  ('POSTURES', ['P', 'AA1', 'S', 'CH', 'ER0', 'Z'], 1),
#  ('MESBICS', ['M', 'EH1', 'S', 'B', 'IH0', 'K', 'S'], 1),
#  ('PANMURE', ['P', 'AE1', 'N', 'M', 'UH2', 'R'], 1),
#  ('HERZOG', ['HH', 'ER1', 'Z', 'AA0', 'G'], 1),
#  ('THREADGILL', ['TH', 'R', 'EH1', 'D', 'G', 'IH2', 'L'], 1),
#  ('PLANERS', ['P', 'L', 'EY1', 'N', 'ER0', 'Z'], 1),
#  ('KARNEY', ['K', 'AA1', 'R', 'N', 'IY0'], 1),
#  ('HARTKE', ['HH', 'AA1', 'R', 'T', 'K', 'IY0'], 1),
#  ('RETHOUGHT', ['R', 'IY0', 'TH', 'AO1', 'T'], 2),
#  ('TURNBOUGH', ['T', 'ER1', 'N', 'B', 'AW2'], 1),
#  ('SUNSPOTS', ['S', 'AH1', 'N', 'S', 'P', 'AA2', 'T', 'S'], 1),
#  ('SCHOENECK', ['SH', 'OW1', 'N', 'EH0', 'K'], 1),
#  ('PAWLIK', ['P', 'AO1', 'L', 'IH0', 'K'], 1),
#  ('BARACK', ['B', 'AA1', 'R', 'AH0', 'K'], 1),
#  ('FIRMA', ['F', 'ER1', 'M', 'AH0'], 1),
#  ('BOTKINS', ['B', 'AA1', 'T', 'K', 'IH0', 'N', 'Z'], 1),
#  ('SEALAND', ['S', 'IY1', 'L', 'AE2', 'N', 'D'], 1),
#  ('BENSTOCK', ['B', 'EH1', 'N', 'S', 'T', 'AA2', 'K'], 1),
#  ('SCORING', ['S', 'K', 'AO1', 'R', 'IH0', 'NG'], 1),
#  ('ZILLER', ['Z', 'IH1', 'L', 'ER0'], 1),
#  ('LAYOFF', ['L', 'EY1', 'AO2', 'F'], 1),
#  ('GEMEX', ['JH', 'EH1', 'M', 'EH0', 'K', 'S'], 1),
#  ('HOWDEN', ['HH', 'AW1', 'D', 'AH0', 'N'], 1),
#  ('RINER', ['R', 'AY1', 'N', 'ER0'], 1),
#  ('DIWA', ['D', 'IY1', 'W', 'AH0'], 1),
#  ('RUSTIN', ['R', 'AH1', 'S', 'T', 'IH0', 'N'], 1),
#  ('MACTAN', ['M', 'AH0', 'K', 'T', 'AE1', 'N'], 2),
#  ('KOVATCH', ['K', 'AA1', 'V', 'AH0', 'CH'], 1),
#  ('WAHLSTROM', ['W', 'AA1', 'L', 'S', 'T', 'R', 'AH0', 'M'], 1),
#  ('HANDLY', ['HH', 'AE1', 'N', 'D', 'L', 'IY0'], 1),
#  ('SPILLMAN', ['S', 'P', 'IH1', 'L', 'M', 'AH0', 'N'], 1),
#  ('CHISELED', ['CH', 'IH1', 'Z', 'AH0', 'L', 'D'], 1),
#  ('SHMOOZER', ['SH', 'M', 'UW1', 'Z', 'ER0'], 1),
#  ('TRIGGERED', ['T', 'R', 'IH1', 'G', 'ER0', 'D'], 1),
#  ('BALDO', ['B', 'AA1', 'L', 'D', 'OW0'], 1),
#  ('CHALSTY', ['CH', 'AE1', 'L', 'S', 'T', 'IY0'], 1),
#  ('MERYL', ['M', 'EH1', 'R', 'AH0', 'L'], 1),
#  ('COHEN', ['K', 'OW1', 'AH0', 'N'], 1),
#  ('VIBRANT', ['V', 'AY1', 'B', 'R', 'AH0', 'N', 'T'], 1),
#  ('SPOUTED', ['S', 'P', 'AW1', 'T', 'AH0', 'D'], 1),
#  ('PINKOS', ['P', 'IH1', 'NG', 'K', 'OW0', 'Z'], 1),
#  ('TARHEELS', ['T', 'AA1', 'R', 'HH', 'IY2', 'L', 'Z'], 1),
#  ('UMSCHEID', ['AH1', 'M', 'SH', 'AY2', 'D'], 1),
#  ('BULAT', ['B', 'UW1', 'L', 'AH0', 'T'], 1),
#  ('FLINCHING', ['F', 'L', 'IH1', 'N', 'CH', 'IH0', 'NG'], 1),
#  ('FLOCKING', ['F', 'L', 'AA1', 'K', 'IH0', 'NG'], 1),
#  ('SANDBERG', ['S', 'AE1', 'N', 'D', 'B', 'ER0', 'G'], 1),
#  ('DUNNELL', ['D', 'AH1', 'N', 'AH0', 'L'], 1),
#  ('SHOCKWAVE', ['SH', 'AA1', 'K', 'W', 'EY2', 'V'], 1),
#  ('BURDELL', ['B', 'ER0', 'D', 'EH1', 'L'], 2),
#  ('LYNAM', ['L', 'IH1', 'N', 'AH0', 'M'], 1),
#  ('REXFORD', ['R', 'EH1', 'K', 'S', 'F', 'ER0', 'D'], 1),
#  ('SHAWGO', ['SH', 'AO1', 'G', 'OW2'], 1),
#  ('MYSTICS', ['M', 'IH1', 'S', 'T', 'IH0', 'K', 'S'], 1),
#  ('SKALSKY', ['S', 'K', 'AA1', 'L', 'S', 'K', 'IY0'], 1),
#  ('ODDER', ['AA1', 'D', 'ER0'], 1),
#  ('RECANT', ['R', 'IY0', 'K', 'AE1', 'N', 'T'], 2),
#  ('CHARLIE', ['CH', 'AA1', 'R', 'L', 'IY0'], 1),
#  ('KEMPEN', ['K', 'EH1', 'M', 'P', 'AH0', 'N'], 1),
#  ('KICKBACKS', ['K', 'IH1', 'K', 'B', 'AE2', 'K', 'S'], 1),
#  ('HEINY', ['HH', 'AY1', 'N', 'IY0'], 1),
#  ('NIHEI', ['N', 'IH0', 'HH', 'EY1'], 2),
#  ('WERRY', ['W', 'EH1', 'R', 'IY0'], 1),
#  ('BIRDHOUSE', ['B', 'ER1', 'D', 'HH', 'AW0', 'S'], 1),
#  ('BERGEMAN', ['B', 'ER1', 'G', 'M', 'AH0', 'N'], 1),
#  ('HERGOTT', ['HH', 'ER1', 'G', 'AH0', 'T'], 1),
#  ('DEPAZ', ['D', 'AH0', 'P', 'AE1', 'Z'], 2),
#  ('AXES', ['AE1', 'K', 'S', 'IH2', 'Z'], 1),
#  ('LITTMANN', ['L', 'IH1', 'T', 'M', 'AH0', 'N'], 1),
#  ('BEAMAN', ['B', 'IY1', 'M', 'AH0', 'N'], 1),
#  ('HISEY', ['HH', 'IH1', 'S', 'IY0'], 1),
#  ('KOSKA', ['K', 'OW1', 'S', 'K', 'AH0'], 1),
#  ('YETMAN', ['Y', 'EH1', 'T', 'M', 'AH0', 'N'], 1),
#  ('QUESTROM', ['K', 'W', 'EH1', 'S', 'T', 'R', 'AH0', 'M'], 1),
#  ('SCALZO', ['S', 'K', 'AA1', 'L', 'Z', 'OW0'], 1),
#  ('FOREARM', ['F', 'AO0', 'R', 'AA1', 'R', 'M'], 2),
#  ('STOECKLE', ['S', 'T', 'OW1', 'K', 'AH0', 'L'], 1),
#  ('SIMONE', ['S', 'IH0', 'M', 'OW1', 'N'], 2),
#  ('ORTHO', ['AO1', 'R', 'TH', 'OW2'], 1),
#  ('BRIEGEL', ['B', 'R', 'IY1', 'G', 'AH0', 'L'], 1),
#  ('BOZO', ['B', 'OW1', 'Z', 'OW2'], 1),
#  ('TAKING', ['T', 'EY1', 'K', 'IH0', 'NG'], 1),
#  ('BARCA', ['B', 'AA1', 'R', 'K', 'AH0'], 1),
#  ('MEHLHAFF', ['M', 'EH1', 'L', 'HH', 'AH0', 'F'], 1),
#  ('FRAGA', ['F', 'R', 'AA1', 'G', 'AH0'], 1),
#  ('AUCOTT', ['AO1', 'K', 'AA2', 'T'], 1),
#  ('WARMLY', ['W', 'AO1', 'R', 'M', 'L', 'IY0'], 1),
#  ('ALBRO', ['AE1', 'L', 'B', 'R', 'OW0'], 1),
#  ('PREDMORE', ['P', 'R', 'EH1', 'D', 'M', 'AO0', 'R'], 1),
#  ('STRUTTON', ['S', 'T', 'R', 'AH1', 'T', 'AH0', 'N'], 1),
#  ('GRAPESHOT', ['G', 'R', 'EY1', 'P', 'SH', 'AA2', 'T'], 1),
#  ('BUILDING', ['B', 'IH1', 'L', 'D', 'IH0', 'NG'], 1),
#  ('HEILEMAN', ['HH', 'AY1', 'L', 'M', 'AH0', 'N'], 1),
#  ('EXCITES', ['IH0', 'K', 'S', 'AY1', 'T', 'S'], 2),
#  ('DUCKWALL', ['D', 'AH1', 'K', 'W', 'AO2', 'L'], 1),
#  ('MAXTON', ['M', 'AE1', 'K', 'S', 'T', 'AH0', 'N'], 1),
#  ('KENYON', ['K', 'EH1', 'N', 'Y', 'AH0', 'N'], 1),
#  ('CURSES', ['K', 'ER1', 'S', 'IH0', 'Z'], 1),
#  ('NGO', ['EH0', 'NG', 'G', 'OW1'], 2),
#  ('URIE', ['Y', 'ER1', 'IY0'], 1),
#  ('UNVEIL', ['AH0', 'N', 'V', 'EY1', 'L'], 2),
#  ('CALLING', ['K', 'AO1', 'L', 'IH0', 'NG'], 1),
#  ('DUVALL', ['D', 'UW0', 'V', 'AA1', 'L'], 2),
#  ('SPEISER', ['S', 'P', 'AY1', 'Z', 'ER0'], 1),
#  ('CURBY', ['K', 'ER1', 'B', 'IY0'], 1),
#  ('WESTCOAST', ['W', 'EH1', 'S', 'T', 'K', 'OW2', 'S', 'T'], 1),
#  ('GILLINGS', ['G', 'IH1', 'L', 'IH0', 'NG', 'Z'], 1),
#  ('ENDURED', ['EH0', 'N', 'D', 'Y', 'UH1', 'R', 'D'], 2),
#  ('APPALL', ['AH0', 'P', 'AO1', 'L'], 2),
#  ('ANGLOS', ['AE1', 'NG', 'G', 'L', 'OW0', 'Z'], 1),
#  ('THUMAN', ['TH', 'UW1', 'M', 'AH0', 'N'], 1),
#  ('POULENC', ['P', 'UW1', 'L', 'AH0', 'NG', 'K'], 1),
#  ('KLUGER', ['K', 'L', 'UW1', 'G', 'ER0'], 1),
#  ('JOELLE', ['JH', 'OW0', 'EH1', 'L'], 2),
#  ('HODSON', ['HH', 'AA1', 'D', 'S', 'AH0', 'N'], 1),
#  ('BOOTIES', ['B', 'UW1', 'T', 'IY0', 'Z'], 1),
#  ('HAGGLED', ['HH', 'AE1', 'G', 'AH0', 'L', 'D'], 1),
#  ('IVEN', ['AY1', 'V', 'AH0', 'N'], 1),
#  ('DENTZER', ['D', 'EH1', 'N', 'T', 'Z', 'ER0'], 1),
#  ('GRIGNON', ['G', 'R', 'IH1', 'G', 'N', 'AH0', 'N'], 1),
#  ('FORINT', ['F', 'AO1', 'R', 'IH0', 'N', 'T'], 1),
#  ('SWEDEN', ['S', 'W', 'IY1', 'D', 'AH0', 'N'], 1),
#  ('THIESSEN', ['TH', 'IY1', 'S', 'AH0', 'N'], 1),
#  ('TITANS', ['T', 'AY1', 'T', 'AH0', 'N', 'Z'], 1),
#  ('HIGHSCHOOL', ['HH', 'AY1', 'S', 'K', 'UW2', 'L'], 1),
#  ('DARLINE', ['D', 'AA1', 'R', 'L', 'AY2', 'N'], 1),
#  ('HANSCHE', ['HH', 'AE1', 'N', 'SH', 'IY0'], 1),
#  ('GOELLNER', ['G', 'OW1', 'L', 'N', 'ER0'], 1),
#  ('RHINEHART', ['R', 'AY1', 'N', 'HH', 'AA2', 'R', 'T'], 1),
#  ('REPELS', ['R', 'IH0', 'P', 'EH1', 'L', 'Z'], 2),
#  ('SANSOM', ['S', 'AE1', 'N', 'S', 'AH0', 'M'], 1),
#  ('TRESTER', ['T', 'R', 'EH1', 'S', 'T', 'ER0'], 1),
#  ('KONIG', ['K', 'AA1', 'N', 'IH0', 'G'], 1),
#  ('SPINNER', ['S', 'P', 'IH1', 'N', 'ER0'], 1),
#  ('SALLES', ['S', 'AA1', 'L', 'EH0', 'S'], 1),
#  ('LAFOSSE', ['L', 'AA0', 'F', 'AA1', 'S'], 2),
#  ('BALDRY', ['B', 'AO1', 'L', 'D', 'R', 'IY0'], 1),
#  ('MILLI', ['M', 'IH1', 'L', 'IY0'], 1),
#  ('KIMMEY', ['K', 'IH1', 'M', 'IY0'], 1),
#  ('PINKER', ['P', 'IH1', 'NG', 'K', 'ER0'], 1),
#  ('KAPLAN', ['K', 'AE1', 'P', 'L', 'AH0', 'N'], 1),
#  ('DOUCET', ['D', 'UW0', 'S', 'EH1', 'T'], 2),
#  ('HORUS', ['HH', 'AO1', 'R', 'AH0', 'S'], 1),
#  ('IRVIN', ['ER1', 'V', 'IH0', 'N'], 1),
#  ('HARREL', ['HH', 'AE1', 'R', 'AH0', 'L'], 1),
#  ('THREEMONTH', ['TH', 'R', 'IY1', 'M', 'AH0', 'N', 'TH'], 1),
#  ('HARDEST', ['HH', 'AA1', 'R', 'D', 'AH0', 'S', 'T'], 1),
#  ('GRIMSLEY', ['G', 'R', 'IH1', 'M', 'Z', 'L', 'IY0'], 1),
#  ('HALBROOK', ['HH', 'AE1', 'L', 'B', 'R', 'UH0', 'K'], 1),
#  ('INHALED', ['IH2', 'N', 'HH', 'EY1', 'L', 'D'], 2),
#  ('ACKLES', ['AE1', 'K', 'AH0', 'L', 'Z'], 1),
#  ('BADU', ['B', 'AH0', 'D', 'UW1'], 2),
#  ('DULONG', ['D', 'Y', 'UW1', 'L', 'AO0', 'NG'], 1),
#  ('BERGMAN', ['B', 'ER1', 'G', 'M', 'AH0', 'N'], 1),
#  ('STIRRUPS', ['S', 'T', 'ER1', 'AH0', 'P', 'S'], 1),
#  ('DOLPHINS', ['D', 'AA1', 'L', 'F', 'AH0', 'N', 'Z'], 1),
#  ('SIDETRACKED', ['S', 'AY1', 'D', 'T', 'R', 'AE2', 'K', 'T'], 1),
#  ('FRYAR', ['F', 'R', 'AY1', 'ER0'], 1),
#  ('BROWER', ['B', 'R', 'AW1', 'ER0'], 1),
#  ('BRUSCA', ['B', 'R', 'AH1', 'S', 'K', 'AH0'], 1),
#  ('MISTER', ['M', 'IH1', 'S', 'T', 'ER0'], 1),
#  ('PREMIERES', ['P', 'R', 'EH0', 'M', 'IH1', 'R', 'Z'], 2),
#  ('LAZEAR', ['L', 'AH0', 'Z', 'IH1', 'R'], 2),
#  ('CASAL', ['K', 'AA0', 'S', 'AA1', 'L'], 2),
#  ('KUIPERS', ['K', 'UW1', 'P', 'ER0', 'Z'], 1),
#  ('ALIX', ['AE1', 'L', 'IH0', 'K', 'S'], 1),
#  ('CRUEY', ['K', 'R', 'AH1', 'IY0'], 1),
#  ('MORSELS', ['M', 'AO1', 'R', 'S', 'AH0', 'L', 'Z'], 1),
#  ('MUNLEY', ['M', 'AH1', 'N', 'L', 'IY0'], 1),
#  ('TRAMPLED', ['T', 'R', 'AE1', 'M', 'P', 'AH0', 'L', 'D'], 1),
#  ('SISTI', ['S', 'IH1', 'S', 'T', 'IY0'], 1),
#  ('MILROY', ['M', 'IH1', 'L', 'R', 'OY2'], 1),
#  ('STRICKLAND', ['S', 'T', 'R', 'IH1', 'K', 'L', 'AH0', 'N', 'D'], 1),
#  ('KNITTED', ['N', 'IH1', 'T', 'AH0', 'D'], 1),
#  ('CONTRIVE', ['K', 'AH0', 'N', 'T', 'R', 'AY1', 'V'], 2),
#  ('DODDRIDGE', ['D', 'AA1', 'D', 'R', 'IH0', 'JH'], 1),
#  ('ETESS', ['EH2', 'T', 'EH1', 'S'], 2),
#  ('PILFERED', ['P', 'IH1', 'L', 'F', 'ER0', 'D'], 1),
#  ('NEXIS', ['N', 'EH1', 'K', 'S', 'IH0', 'S'], 1),
#  ('BURRAGE', ['B', 'ER1', 'IH0', 'JH'], 1),
#  ('SUNI', ['S', 'UW1', 'N', 'IY0'], 1),
#  ('RIKELD', ['R', 'AY1', 'K', 'EH0', 'L', 'D'], 1),
#  ('TAMPER', ['T', 'AE1', 'M', 'P', 'ER0'], 1),
#  ('DALLIED', ['D', 'AE1', 'L', 'IY0', 'D'], 1),
#  ('TUNDRA', ['T', 'AH1', 'N', 'D', 'R', 'AH0'], 1),
#  ('WRINGER', ['R', 'IH1', 'NG', 'ER0'], 1),
#  ('NESSI', ['N', 'EH1', 'S', 'IY0'], 1),
#  ('HOWELLS', ['HH', 'AW1', 'AH0', 'L', 'Z'], 1),
#  ('CANA', ['K', 'AE1', 'N', 'AH0'], 1),
#  ('STODGHILL', ['S', 'T', 'AA1', 'JH', 'HH', 'IH2', 'L'], 1),
#  ('HERMIE', ['HH', 'ER1', 'M', 'IY0'], 1),
#  ('NEUPERT', ['N', 'UW1', 'P', 'ER0', 'T'], 1),
#  ('GOEDECKE', ['G', 'OW1', 'D', 'IH0', 'K'], 1),
#  ('FLAGSTAR', ['F', 'L', 'AE1', 'G', 'S', 'T', 'AA2', 'R'], 1),
#  ('ANO', ['AE1', 'N', 'OW0'], 1),
#  ('SINGLAUB', ['S', 'IH1', 'NG', 'L', 'AW2', 'B'], 1),
#  ('LINDON', ['L', 'IH1', 'N', 'D', 'AH0', 'N'], 1),
#  ('COLLIN', ['K', 'AA1', 'L', 'IH0', 'N'], 1),
#  ('AILEEN', ['AY0', 'L', 'IY1', 'N'], 2),
#  ('GLASSCO', ['G', 'L', 'AE1', 'S', 'K', 'OW0'], 1),
#  ('LEGATE', ['L', 'EH1', 'G', 'AH0', 'T'], 1),
#  ('BUMPERS', ['B', 'AH1', 'M', 'P', 'ER0', 'Z'], 1),
#  ('NICHOLE', ['N', 'IH1', 'K', 'OW0', 'L'], 1),
#  ('MOCHEL', ['M', 'AA1', 'K', 'AH0', 'L'], 1),
#  ('MAWKISH', ['M', 'AO1', 'K', 'IH0', 'SH'], 1),
#  ('JAROSZ', ['Y', 'AA1', 'R', 'AH0', 'SH'], 1),
#  ('FOOLING', ['F', 'UW1', 'L', 'IH0', 'NG'], 1),
#  ('RIEHLE', ['R', 'IY1', 'HH', 'AH0', 'L'], 1),
#  ('GUMMY', ['G', 'AH1', 'M', 'IY0'], 1),
#  ('PLAYING', ['P', 'L', 'EY1', 'IH0', 'NG'], 1),
#  ('WEARHOUSE', ['W', 'EH1', 'R', 'HH', 'AW2', 'S'], 1),
#  ('STALLKAMP', ['S', 'T', 'AO1', 'L', 'K', 'AE2', 'M', 'P'], 1),
#  ('EGER', ['IY1', 'G', 'ER0'], 1),
#  ('BADGETT', ['B', 'AE1', 'JH', 'IH0', 'T'], 1),
#  ('CUPPLES', ['K', 'AH1', 'P', 'AH0', 'L', 'Z'], 1),
#  ('SOBBING', ['S', 'AA1', 'B', 'IH0', 'NG'], 1),
#  ('KINSLOW', ['K', 'IH1', 'N', 'S', 'L', 'OW2'], 1),
#  ('SPORTSCLUB', ['S', 'P', 'AO1', 'R', 'T', 'S', 'K', 'L', 'AH2', 'B'], 1),
#  ('SHOFNER', ['SH', 'AA1', 'F', 'N', 'ER0'], 1),
#  ('RUYBAL', ['R', 'AY1', 'B', 'AH0', 'L'], 1),
#  ('SCHAAFSMA', ['SH', 'AA1', 'F', 'S', 'M', 'AH0'], 1),
#  ('VERHAGE', ['V', 'ER1', 'HH', 'IH0', 'JH'], 1),
#  ('WARBURG', ['W', 'AO1', 'R', 'B', 'ER0', 'G'], 1),
#  ('STEAMY', ['S', 'T', 'IY1', 'M', 'IY0'], 1),
#  ('STOWERS', ['S', 'T', 'OW1', 'ER0', 'Z'], 1),
#  ('LOUISETTE', ['L', 'W', 'IY0', 'Z', 'EH1', 'T'], 2),
#  ('UNNAMED', ['AH0', 'N', 'N', 'EY1', 'M', 'D'], 2),
#  ('RAMUS', ['R', 'EY1', 'M', 'AH0', 'S'], 1),
#  ('LODESTAR', ['L', 'OW1', 'D', 'S', 'T', 'AA2', 'R'], 1),
#  ('SALICK', ['S', 'AE1', 'L', 'IH0', 'K'], 1),
#  ('HAWKEN', ['HH', 'AO1', 'K', 'AH0', 'N'], 1),
#  ('ALFIE', ['AE1', 'L', 'F', 'IY0'], 1),
#  ('FARTING', ['F', 'AA1', 'R', 'T', 'IH0', 'NG'], 1),
#  ('CAMELS', ['K', 'AE1', 'M', 'AH0', 'L', 'Z'], 1),
#  ('WOOTTON', ['W', 'UW1', 'T', 'AH0', 'N'], 1),
#  ('STANCIL', ['S', 'T', 'AE1', 'N', 'S', 'IH0', 'L'], 1),
#  ('LEPPARD', ['L', 'EH1', 'P', 'ER0', 'D'], 1),
#  ('POULTER', ['P', 'OW1', 'L', 'T', 'ER0'], 1),
#  ('RICKERT', ['R', 'IH1', 'K', 'ER0', 'T'], 1),
#  ('BERRY', ['B', 'EH1', 'R', 'IY0'], 1),
#  ('EYESIGHT', ['AY1', 'S', 'AY2', 'T'], 1),
#  ('BEXLEY', ['B', 'EH1', 'K', 'S', 'L', 'IY0'], 1),
#  ('PURNELL', ['P', 'ER1', 'N', 'AH0', 'L'], 1),
#  ('DERIK', ['D', 'EH1', 'R', 'IH0', 'K'], 1),
#  ('TROOPING', ['T', 'R', 'UW1', 'P', 'IH0', 'NG'], 1),
#  ('TROUTWINE', ['T', 'R', 'AW1', 'T', 'W', 'AY2', 'N'], 1),
#  ('PLEASURES', ['P', 'L', 'EH1', 'ZH', 'ER0', 'Z'], 1),
#  ('BEADLE', ['B', 'IY1', 'D', 'AH0', 'L'], 1),
#  ('GOPI', ['G', 'OW1', 'P', 'IY0'], 1),
#  ('MORFIN', ['M', 'AO1', 'R', 'F', 'IH0', 'N'], 1),
#  ('FOSKETT', ['F', 'AA1', 'S', 'K', 'IH0', 'T'], 1),
#  ('NOLDEN', ['N', 'OW1', 'L', 'D', 'AH0', 'N'], 1),
#  ('BALDUS', ['B', 'AA1', 'L', 'D', 'IH0', 'S'], 1),
#  ('HOUSEWARE', ['HH', 'AW1', 'S', 'W', 'EH2', 'R'], 1),
#  ('ALAIN', ['AH0', 'L', 'EY1', 'N'], 2),
#  ('MYRTLES', ['M', 'ER1', 'T', 'AH0', 'L', 'Z'], 1),
#  ('DECLERK', ['D', 'AH0', 'K', 'L', 'ER1', 'K'], 2),
#  ('GRAVESIDE', ['G', 'R', 'EY1', 'V', 'S', 'AY2', 'D'], 1),
#  ('CULWELL', ['K', 'AH1', 'L', 'W', 'EH2', 'L'], 1),
#  ('RACEHORSE', ['R', 'EY1', 'S', 'HH', 'AO2', 'R', 'S'], 1),
#  ('GUAVAS', ['G', 'W', 'AA1', 'V', 'AH0', 'Z'], 1),
#  ('AMDEC', ['AE1', 'M', 'D', 'EH2', 'K'], 1),
#  ('CAFTAN', ['K', 'AE1', 'F', 'T', 'AE2', 'N'], 1),
#  ('CONFRERES', ['K', 'AA1', 'N', 'F', 'R', 'EH0', 'R', 'Z'], 1),
#  ('ELKHART', ['EH1', 'L', 'K', 'HH', 'AA2', 'R', 'T'], 1),
#  ('TASM', ['T', 'AE1', 'S', 'AH0', 'M'], 1),
#  ('CLYBURN', ['K', 'L', 'IH1', 'B', 'ER0', 'N'], 1),
#  ('BARKETT', ['B', 'AA1', 'R', 'K', 'IH0', 'T'], 1),
#  ('GETHERS', ['G', 'EH1', 'DH', 'ER0', 'Z'], 1),
#  ('VOLUMES', ['V', 'AA1', 'L', 'Y', 'UW0', 'M', 'Z'], 1),
#  ('ALONGE', ['AE1', 'L', 'AH0', 'N', 'JH'], 1),
#  ('HUGELY', ['HH', 'Y', 'UW1', 'JH', 'L', 'IY0'], 1),
#  ('MCVAY', ['M', 'AH0', 'K', 'V', 'EY1'], 2),
#  ('GRUSHOW', ['G', 'R', 'AH1', 'SH', 'OW0'], 1),
#  ('HALSTON', ['HH', 'AO1', 'L', 'S', 'T', 'AH0', 'N'], 1),
#  ('STIREWALT', ['S', 'T', 'ER1', 'W', 'AA2', 'L', 'T'], 1),
#  ('FOXY', ['F', 'AA1', 'K', 'S', 'IY0'], 1),
#  ('VALLANCE', ['V', 'AE1', 'L', 'AH0', 'N', 'S'], 1),
#  ('OUTGO', ['AW1', 'T', 'G', 'OW2'], 1),
#  ('POWDER', ['P', 'AW1', 'D', 'ER0'], 1),
#  ('MUNOZ', ['M', 'UW1', 'N', 'Y', 'OW0', 'Z'], 1),
#  ('FRAZZLED', ['F', 'R', 'AE1', 'Z', 'AH0', 'L', 'D'], 1),
#  ('LUDDY', ['L', 'AH1', 'D', 'IY0'], 1),
#  ('PROFILE', ['P', 'R', 'OW1', 'F', 'AY2', 'L'], 1),
#  ('REDMANN', ['R', 'EH1', 'D', 'M', 'AH0', 'N'], 1),
#  ('MCCOOL', ['M', 'AH0', 'K', 'UW1', 'L'], 2),
#  ('KOBZA', ['K', 'AA1', 'B', 'Z', 'AH0'], 1),
#  ('WAFERS', ['W', 'EY1', 'F', 'ER0', 'Z'], 1),
#  ('HEADSMAN', ['HH', 'EH1', 'D', 'Z', 'M', 'AH0', 'N'], 1),
#  ...]
